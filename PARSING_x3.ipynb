# %%
import cianparser

# %%
parser = cianparser.CianParser(location="Москва")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_moskva_28_Oct_2024_13_13_29_752490.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 parser = cianparser.CianParser(location="Москва")
# ----> 3 data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
#
# File c:\Users\aaron\intensiv_one\.venv\Lib\site-packages\cianparser\cianparser.py:119, in CianParser.get_flats(self, deal_type, rooms, with_saving_csv, with_extra_data, additional_settings)
# ...

# %% [markdown]
# # Серпухов

# %%
# однушки
parser = cianparser.CianParser(location="Серпухов")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_serpuhov_27_Oct_2024_18_30_57_524752.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4983&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 13 600 000 rub
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 13 600 000 rub
#  1 | 1 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 14 933 333 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://serpukhov.cian.ru/sale/flat/308533764/
# ...

# %%
# двушки
parser = cianparser.CianParser(location="Серпухов")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_serpuhov_27_Oct_2024_18_46_23_317968.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4983&deal_type=sale&offer_type=flat&room2=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                          ] 54% | Count of all parsed: 15. Progress ratio: 1 %. Average price: 15 623 372 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                          ] 54% | Count of all parsed: 15. Progress ratio: 1 %. Average price: 15 623 372 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                          ] 54% | Count of all parsed: 15. Progress ratio: 1 %. Average price: 15 623 372 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://serpukhov.cian.ru/sale/flat/305145683/
# ...

# %%
# трёшки
parser = cianparser.CianParser(location="Серпухов")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_serpuhov_27_Oct_2024_18_56_52_351456.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4983&deal_type=sale&offer_type=flat&room3=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>                                            ] 22% | Count of all parsed: 6. Progress ratio: 1 %. Average price: 14 547 466 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>                                          ] 25% | Count of all parsed: 7. Progress ratio: 1 %. Average price: 15 597 466 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4983&deal_type=sale&offer_type=flat&room3=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 page: 28 offers
#
# ...

# %%
# студии
parser = cianparser.CianParser(location="Серпухов")

data = parser.get_flats(deal_type="sale", rooms=('studio'), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_serpuhov_27_Oct_2024_19_29_45_542425.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4983&deal_type=sale&offer_type=flat&room9=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 2 %. Average price: 11 127 806 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 2 %. Average price: 11 127 806 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>  ] 96% | Count of all parsed: 24. Progress ratio: 2 %. Average price: 11 127 806 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://serpukhov.cian.ru/sale/flat/301489812/
# ...

# %% [markdown]
# # Дубна

# %%
# однушки
parser = cianparser.CianParser(location="Дубна")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_dubna_27_Oct_2024_19_48_25_705291.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4741&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                      ] 61% | Count of all parsed: 17. Progress ratio: 2 %. Average price: 17 850 321 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                      ] 61% | Count of all parsed: 17. Progress ratio: 2 %. Average price: 17 850 321 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                      ] 61% | Count of all parsed: 17. Progress ratio: 2 %. Average price: 17 850 321 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://dubna.cian.ru/sale/flat/307411948/
# ...

# %%
import cianparser

# %%
# двушки
parser = cianparser.CianParser(location="Дубна")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_dubna_27_Oct_2024_20_01_30_050594.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4741&deal_type=sale&offer_type=flat&room2=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 11. Progress ratio: 1 %. Average price: 29 040 899 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>                                      ] 33% | Count of all parsed: 12. Progress ratio: 1 %. Average price: 29 886 482 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 12. Progress ratio: 1 %. Average price: 29 886 482 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://dubna.cian.ru/sale/flat/302775822/
# ...

# %%
# трёшки мск
parser = cianparser.CianParser(location="Москва")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_moskva_27_Oct_2024_20_23_10_922747.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room3=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 2 %. Average price: 352 358 873 rub
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 20. Progress ratio: 2 %. Average price: 352 358 873 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 2 %. Average price: 352 358 873 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/302838498/
# ...

# %%
# двушки
parser = cianparser.CianParser(location="Дубна")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_dubna_27_Oct_2024_21_05_24_170735.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4741&deal_type=sale&offer_type=flat&room3=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>                                    ] 36% | Count of all parsed: 10. Progress ratio: 1 %. Average price: 37 893 181 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 11. Progress ratio: 1 %. Average price: 38 847 727 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 11. Progress ratio: 1 %. Average price: 38 847 727 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://dubna.cian.ru/sale/flat/301773788/
# ...

# %%
# двушки
parser = cianparser.CianParser(location="Ивантеевка")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_ivanteevka_27_Oct_2024_21_25_05_864714.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=flat&room2=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                    ] 65% | Count of all parsed: 18. Progress ratio: 3 %. Average price: 152 476 631 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                    ] 65% | Count of all parsed: 18. Progress ratio: 3 %. Average price: 152 476 631 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                    ] 65% | Count of all parsed: 18. Progress ratio: 3 %. Average price: 152 476 631 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://ekb.cian.ru/sale/flat/308412109/
# ...

# %%
# трёшки
parser = cianparser.CianParser(location="Ивантеевка")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_ivanteevka_27_Oct_2024_21_44_48_754445.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=flat&room3=1
#
# ...
#  1 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 58 564 000 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=flat&room3=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 | 2 page with list: [=>                                                      ] 4% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 65 859 000 rub
#
# ...

# %%
parser = cianparser.CianParser(location="Раменское")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_ramenskoe_27_Oct_2024_22_03_13_485639.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 8 174 690 rub
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 11 119 690 rub
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 11 119 690 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://ramenskoye.cian.ru/sale/flat/303821861/
# ...

# %%
parser = cianparser.CianParser(location="Раменское")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_ramenskoe_27_Oct_2024_22_28_19_353325.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=flat&room2=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                ] 72% | Count of all parsed: 20. Progress ratio: 3 %. Average price: 30 302 692 rub
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 20. Progress ratio: 3 %. Average price: 30 302 692 rub
#  1 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 20. Progress ratio: 3 %. Average price: 30 302 692 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://ramenskoye.cian.ru/sale/flat/299477111/
# ...

# %%
parser = cianparser.CianParser(location="Раменское")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_ramenskoe_27_Oct_2024_22_46_41_267652.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=flat&room3=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                                ] 43% | Count of all parsed: 12. Progress ratio: 2 %. Average price: 24 401 850 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                                ] 43% | Count of all parsed: 12. Progress ratio: 2 %. Average price: 24 401 850 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>                                ] 43% | Count of all parsed: 12. Progress ratio: 2 %. Average price: 24 401 850 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://ramenskoye.cian.ru/sale/flat/297806996/
# ...

# %%
parser = cianparser.CianParser(location="Раменское")

data = parser.get_flats(deal_type="sale", rooms=(4), additional_settings={"start_page": 1, "end_page": 20}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_20_ramenskoe_27_Oct_2024_23_04_28_308460.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175758&deal_type=sale&offer_type=flat&room4=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 64% | Count of all parsed: 16. Progress ratio: 4 %. Average price: 39 328 605 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 64% | Count of all parsed: 16. Progress ratio: 4 %. Average price: 39 328 605 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 64% | Count of all parsed: 16. Progress ratio: 4 %. Average price: 39 328 605 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://ramenskoye.cian.ru/sale/flat/303339560/
# ...

# %%
parser = cianparser.CianParser(location="Домодедово")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_domodedovo_27_Oct_2024_23_29_21_357706.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>      ] 90% | Count of all parsed: 25. Progress ratio: 3 %. Average price: 20 681 747 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 4 %. Average price: 20 860 593 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>    ] 93% | Count of all parsed: 26. Progress ratio: 4 %. Average price: 20 860 593 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://domodedovo.cian.ru/sale/flat/307851654/
# ...

# %%
parser = cianparser.CianParser(location="Домодедово")

data = parser.get_flats(deal_type="sale", rooms=('studio'), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_domodedovo_28_Oct_2024_00_13_40_969795.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=flat&room9=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                              ] 47% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 13 437 962 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                              ] 47% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 13 437 962 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                              ] 47% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 13 437 962 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://domodedovo.cian.ru/sale/flat/306933349/
# ...

# %%
parser = cianparser.CianParser(location="Домодедово")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_domodedovo_28_Oct_2024_00_30_29_269236.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=flat&room2=1
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=flat&room2=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                        ] 58% | Count of all parsed: 16. Progress ratio: 2 %. Average price: 25 730 540 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                        ] 58% | Count of all parsed: 16. Progress ratio: 2 %. Average price: 25 730 540 rub
# ...

# %%
parser = cianparser.CianParser(location="Домодедово")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_domodedovo_28_Oct_2024_00_47_50_360977.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=174640&deal_type=sale&offer_type=flat&room3=1
#
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 11. Progress ratio: 2 %. Average price: 32 211 657 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 11. Progress ratio: 2 %. Average price: 32 211 657 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://domodedovo.cian.ru/sale/flat/306764024/
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 page: 28 offers
# ...

# %%
parser = cianparser.CianParser(location="Дубна")

data = parser.get_flats(deal_type="sale", rooms=('studio'), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_dubna_28_Oct_2024_01_04_41_858623.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4741&deal_type=sale&offer_type=flat&room9=1
#
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                      ] 55% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 35 079 060 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                      ] 55% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 35 079 060 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://dubna.cian.ru/sale/flat/287460793/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# ...

# %%
from time import sleep

# %%
parser = cianparser.CianParser(location="Звенигород")

data = parser.get_flats(deal_type="sale", rooms=('studio'), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_zvenigorod_28_Oct_2024_01_26_50_742591.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4756&deal_type=sale&offer_type=flat&room9=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 3 %. Average price: 13 197 606 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 3 %. Average price: 13 197 606 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>          ] 83% | Count of all parsed: 23. Progress ratio: 3 %. Average price: 13 197 606 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://zvenigorod.cian.ru/sale/flat/303234645/
# ...

# %%
sleep(20)

# %%
parser = cianparser.CianParser(location="Звенигород")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_zvenigorod_28_Oct_2024_01_45_00_757424.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4756&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>                            ] 50% | Count of all parsed: 14. Progress ratio: 2 %. Average price: 15 771 067 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>                            ] 50% | Count of all parsed: 14. Progress ratio: 2 %. Average price: 15 771 067 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                          ] 54% | Count of all parsed: 15. Progress ratio: 2 %. Average price: 16 051 067 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://zvenigorod.cian.ru/sale/flat/305943671/
# ...

# %%
sleep(8)

# %%
parser = cianparser.CianParser(location="Звенигород")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_zvenigorod_28_Oct_2024_02_02_23_340404.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4756&deal_type=sale&offer_type=flat&room2=1
#
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                              ] 47% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 23 793 459 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>                              ] 47% | Count of all parsed: 13. Progress ratio: 2 %. Average price: 23 793 459 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://zvenigorod.cian.ru/sale/flat/309073997/
# The collection of information from the pages with ending parse on 1 page...
#
#
#  2 page: 28 offers
#  2 page: 28 offers
#
# ...

# %%
sleep(16)

# %%
parser = cianparser.CianParser(location="Звенигород")

data = parser.get_flats(deal_type="sale", rooms=(3), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_zvenigorod_28_Oct_2024_02_19_35_312443.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4756&deal_type=sale&offer_type=flat&room3=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>                            ] 50% | Count of all parsed: 14. Progress ratio: 2 %. Average price: 30 703 198 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>                            ] 50% | Count of all parsed: 14. Progress ratio: 2 %. Average price: 30 703 198 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>                            ] 50% | Count of all parsed: 14. Progress ratio: 2 %. Average price: 30 703 198 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://zvenigorod.cian.ru/sale/flat/301399015/
# ...

# %%
sleep(10)

# %%
parser = cianparser.CianParser(location="Москва")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 10, "end_page": 64}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_10_64_moskva_28_Oct_2024_02_39_30_236282.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                  ] 68% | Count of all parsed: 19. Progress ratio: 2 %. Average price: 70 124 985 rub
#  1 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>                      ] 61% | Count of all parsed: 19. Progress ratio: 2 %. Average price: 70 124 985 rub
#  1 | 10 page with list: [=>=>                                                    ] 8% | Count of all parsed: 19. Progress ratio: 2 %. Average price: 70 124 985 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308796915/
# ...

# %%
sleep(23)

# %%
parser = cianparser.CianParser(location="Москва")

data = parser.get_flats(deal_type="sale", rooms=(4), additional_settings={"start_page": 10, "end_page": 64}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_10_64_moskva_28_Oct_2024_03_14_57_309765.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=10&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room4=1
#
# ...
#  1 | 10 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 235 787 266 rub
#  1 | 10 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 29. Progress ratio: 2 %. Average price: 477 502 803 rub
#  2 | 11 page with list: [=>=>=>=>=>                                              ] 18% | Count of all parsed: 33. Progress ratio: 3 %. Average price: 501 102 564 rub
# ...

# %%
sleep(19)

# %%
parser = cianparser.CianParser(location="Котельники")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_kotelniki_28_Oct_2024_08_10_10_735088.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=flat&room1=1
#
# ...
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 2 %. Average price: 85 973 012 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>                                      ] 33% | Count of all parsed: 37. Progress ratio: 3 %. Average price: 90 140 250 rub
#  2 | 2 page with list: [=>=>=>=>=>=>=>=>=>=>                                    ] 36% | Count of all parsed: 38. Progress ratio: 3 %. Average price: 90 287 356 rub
# ...

# %%
sleep(17)

# %%
parser = cianparser.CianParser(location="Котельники")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 54}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_54_kotelniki_28_Oct_2024_11_17_15_977600.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=None&deal_type=sale&offer_type=flat&room2=1
#
# ...
#  1 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 22 622 160 rub
#  1 | 1 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 86 391 760 rub
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>                                  ] 40% | Count of all parsed: 11. Progress ratio: 1 %. Average price: 124 711 432 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/308490853/
# ...

# %%
sleep(20)

# %%
parser = cianparser.CianParser(location="Одинцово")

data = parser.get_flats(deal_type="sale", rooms=(4), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_odintsovo_28_Oct_2024_12_18_26_908222.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175578&deal_type=sale&offer_type=flat&room4=1
#
#  1 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://odintsovo.cian.ru/sale/flat/308938542/
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=175578&deal_type=sale&offer_type=flat&room4=1
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# ...

# %%
sleep(22)

# %%
parser = cianparser.CianParser(location="Одинцово")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 30, "end_page": 86}, with_extra_data=True, with_saving_csv=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 parser = cianparser.CianParser(location="Одинцово")
#       3 data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 30, "end_page": 86}, with_extra_data=True, with_saving_csv=True)
#
# NameError: name 'cianparser' is not defined

# %%
sleep(10)

# %%
sleep(17)

# %%
parser = cianparser.CianParser(location="Химки")

data = parser.get_flats(deal_type="sale", rooms=('studio'), additional_settings={"start_page": 1, "end_page": 15}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_15_himki_28_Oct_2024_13_20_00_971386.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=5044&deal_type=sale&offer_type=flat&room9=1
#
# ...
# 10
# 4
# 12 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 10 695 595 rub
# 8
# 14 | 1 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 14 095 595 rub
# 6
# 26 | 1 page with list: [=>=>=>=>                                                ] 15% | Count of all parsed: 4. Progress ratio: 1 %. Average price: 15 545 995 rub
# 8
# 4
# ...

# %%
sleep(19)

# %%
parser = cianparser.CianParser(location="Химки")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 54, "end_page": 100}, with_extra_data=True, with_saving_csv=True)

# %%
sleep(21)

# %%
parser = cianparser.CianParser(location="Королёв")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 15}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_15_korolev_28_Oct_2024_16_56_43_187853.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4813&deal_type=sale&offer_type=flat&room1=1
#
# ...
# 8
# 10 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 10 411 700 rub
# 28 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 14 211 700 rub
# 12
# 8
# 81 | 1 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 1 %. Average price: 16 045 033 rub
# ...

# %%
sleep(13)

# %%
parser = cianparser.CianParser(location="Королёв")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 30}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_30_korolev_28_Oct_2024_19_26_20_395250.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4813&deal_type=sale&offer_type=flat&room2=1
#
# ...
# 8
# 10 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 16 268 564 rub
# 81 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 19 793 564 rub
# 10 | 1 page with list: [=>=>=>=>=>=>=>                                          ] 25% | Count of all parsed: 7. Progress ratio: 1 %. Average price: 33 037 970 rub
# ...

# %%
sleep(20)

# %%
parser = cianparser.CianParser(location="Королёв")

data = parser.get_flats(deal_type="sale", rooms=('studio'), additional_settings={"start_page": 1, "end_page": 10}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_10_korolev_28_Oct_2024_22_24_58_699537.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=4813&deal_type=sale&offer_type=flat&room9=1
#
# ...
# 12 | 1 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 5 998 900 rub
# 8
# 20 | 1 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 8 598 900 rub
# 20 | 1 page with list: [=>=>=>=>                                                ] 15% | Count of all parsed: 4. Progress ratio: 2 %. Average price: 10 800 700 rub
# 4
# ...

# %%
sleep(10)

# %%
parser = cianparser.CianParser(location="Руза")

data = parser.get_flats(deal_type="sale", rooms=(2), additional_settings={"start_page": 1, "end_page": 10}, with_extra_data=True, with_saving_csv=True)
# Out:
#                               Preparing to collect information from pages..
# The absolute path to the file:
# c:\Users\aaron\intensiv_one\cian_flat_sale_1_10_ruza_29_Oct_2024_00_07_55_774353.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=175785&deal_type=sale&offer_type=flat&room2=1
#
# ...
# 22
# 10
# 6
# 24 | 1 page with list: [=>                                                        ] 4% | Count of all parsed: 1. Progress ratio: 1 %. Average price: 3 800 000 rub
# 10
# 22 | 1 page with list: [=>=>                                                      ] 7% | Count of all parsed: 2. Progress ratio: 1 %. Average price: 5 900 000 rub
# 10
# 8
# 22 | 1 page with list: [=>=>=>                                                    ] 11% | Count of all parsed: 3. Progress ratio: 2 %. Average price: 7 100 000 rub
# 10
# ...

# %%
sleep(7)

# %%
parser = cianparser.CianParser(location="Дмитров")

data = parser.get_flats(deal_type="sale", rooms=(5), additional_settings={"start_page": 1, "end_page": 8}, with_extra_data=True, with_saving_csv=True)

# %%
sleep(11)

# %%
parser = cianparser.CianParser(location="Дмитров")

data = parser.get_flats(deal_type="sale", rooms=(4), additional_settings={"start_page": 1, "end_page": 8}, with_extra_data=True, with_saving_csv=True)

# %%
sleep(18)

# %%
parser = cianparser.CianParser(location="Дмитров")

data = parser.get_flats(deal_type="sale", rooms=(1), additional_settings={"start_page": 1, "end_page": 8}, with_extra_data=True, with_saving_csv=True)
