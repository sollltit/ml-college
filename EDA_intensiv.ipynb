# %%
# библиотеки
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Домклик ˚ ༘ ⋆｡˚🦕

# %% [markdown]
# ---

# %%
df = pd.read_csv('/content/drive/MyDrive/ml_intensiv_oct.csv', sep = ',',  low_memory=False)
df.head(10)
# Out:
#            id offer_type  object_info.floor  object_info.rooms  \
# 0  2061948793       flat                5.0                  5
# 1  2049601828       flat                5.0                  2
# 2  2060417160       flat                3.0                  3
# 3  2062051930       flat               10.0                  2
# 4  2061047680       flat                8.0                  2
# 5  2057161978       flat                2.0                  5
# 6  2061867164       flat                7.0                  2
# 7  1645403490       flat                4.0                  3
# 8  2062158774       flat                6.0                  1
# 9  2058141024       flat               12.0                  2
#
#    object_info.area  price_info.price  price_info.square_price  \
# 0             314.5         220000000                   699523
# 1              42.0          13400000                   319047
# 2              83.0          23500000                   283132
# 3              56.7          22232323                   392104
# 4              56.6          17700000                   312720
# 5              97.0          55000000                   567010
# 6              60.4          31900000                   528145
# 7             160.0         241850500                  1511565
# 8              35.2          12500000                   355113
# 9              51.9          16100000                   310211
#
#    address.position.lat  address.position.lon seller.agent.is_agent  ...  \
# 0             55.763930             37.642841                 False  ...
# 1             55.807319             37.462047                  True  ...
# 2             55.808079             37.583077                 False  ...
# 3             55.737997             37.482591                 False  ...
# 4             55.604392             37.534757                  True  ...
# 5             55.741191             37.630131                  True  ...
# 6             55.878344             37.479239                 False  ...
# 7             55.742767             37.600801                 False  ...
# 8             55.706152             37.666153                 False  ...
# 9             55.715614             37.457323                  True  ...
#
#   address.parent_id address.locality.id  address.locality.kind  \
# 0         1260200.0                2299               province
# 1           75141.0                2299               province
# 2       300075664.0                2299               province
# 3           73339.0                2299               province
# 4            7493.0                2299               province
# 5           23797.0                2299               province
# 6          102205.0                2299               province
# 7            8211.0                2299               province
# 8          154362.0                2299               province
# 9       300018115.0                2299               province
#
#   address.locality.subkind  address.locality.parent_id legal_options.is_owner  \
# 0                   region                       541.0                  False
# 1                   region                       541.0                  False
# 2                   region                       541.0                  False
# 3                   region                       541.0                  False
# 4                   region                       541.0                  False
# 5                   region                       541.0                  False
# 6                   region                       541.0                  False
# 7                   region                       541.0                  False
# 8                   region                       541.0                  False
# 9                   region                       541.0                  False
#
#   legal_options.is_agent_owner_approved  pessimization.pessimized  \
# 0                                 False                     False
# 1                                  True                     False
# 2                                  True                     False
# 3                                 False                     False
# 4                                  True                     False
# 5                                 False                     False
# 6                                 False                     False
# 7                                 False                     False
# 8                                 False                     False
# 9                                 False                     False
#
#   pessimization.pessimization_type house.floors
# 0                              NaN            5
# 1                              NaN            5
# 2                              NaN           10
# 3                              NaN           14
# 4                              NaN           22
# 5                              NaN            8
# 6                              NaN           30
# 7                              NaN            5
# 8                              NaN           12
# 9                              NaN           12
#
# [10 rows x 40 columns]

# %%
# размер датасета
df.shape
# Out:
# (20073, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20073 entries, 0 to 20072
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     20073 non-null  int64
#  1   offer_type                             20073 non-null  object
#  2   object_info.floor                      17580 non-null  float64
#  3   object_info.rooms                      20073 non-null  int64
#  4   object_info.area                       20073 non-null  float64
#  5   price_info.price                       20073 non-null  int64
#  6   price_info.square_price                20073 non-null  int64
#  7   address.position.lat                   20073 non-null  float64
#  8   address.position.lon                   20073 non-null  float64
#  9   seller.agent.is_agent                  17580 non-null  object
#  10  published_dt                           20073 non-null  object
#  11  updated_dt                             17580 non-null  object
#  12  trade_in                               20073 non-null  bool
#  13  source                                 20073 non-null  object
#  14  ipoteka_rate                           17580 non-null  float64
#  15  has_advance_payment                    17580 non-null  object
#  16  is_exclusive                           6276 non-null   object
#  17  status                                 20073 non-null  int64
#  18  assignment_sale                        17580 non-null  object
#  19  online_show                            6884 non-null   object
#  20  last_price_history_state               9151 non-null   object
#  21  is_placement_paid                      17580 non-null  object
#  22  discount_status.status                 15584 non-null  object
#  23  discount_status.value                  11042 non-null  float64
#  24  duplicates_offer_count                 17580 non-null  float64
#  25  chat_available                         20073 non-null  bool
#  26  is_auction                             20073 non-null  bool
#  27  address.id                             20073 non-null  int64
#  28  address.kind                           20073 non-null  object
#  29  address.guid                           20073 non-null  object
#  30  address.parent_id                      17198 non-null  float64
#  31  address.locality.id                    20073 non-null  int64
#  32  address.locality.kind                  20073 non-null  object
#  33  address.locality.subkind               19122 non-null  object
#  34  address.locality.parent_id             17575 non-null  float64
#  35  legal_options.is_owner                 17580 non-null  object
#  36  legal_options.is_agent_owner_approved  17580 non-null  object
#  37  pessimization.pessimized               17566 non-null  object
#  38  pessimization.pessimization_type       3 non-null      object
#  39  house.floors                           20073 non-null  int64
# dtypes: bool(3), float64(9), int64(8), object(20)
# memory usage: 5.7+ MB

# %% [markdown]
# В колонке "pessimization.pessimization_type" всего 3 ненулевых значения, в колонках "is_exclusive", "online_show", "last_price_history_state" много пропусков.
# Дропаем их + "id", "pessimization.pessimized", "is_auction", "chat_available", "duplicates_offer_count", "legal_options.is_owner", "legal_options.is_agent_owner_approved"

# %%
df.drop(['pessimization.pessimized', 'pessimization.pessimization_type', 'legal_options.is_owner', 'legal_options.is_agent_owner_approved', 'id', 'is_auction', 'chat_available', 'duplicates_offer_count', 'online_show', 'is_exclusive', 'last_price_history_state'], axis=1,inplace=True)

# %%
# оставшиеся колонки
df.columns
# Out:
# Index(['offer_type', 'object_info.floor', 'object_info.rooms',
#        'object_info.area', 'price_info.price', 'price_info.square_price',
#        'address.position.lat', 'address.position.lon', 'seller.agent.is_agent',
#        'published_dt', 'updated_dt', 'trade_in', 'source', 'ipoteka_rate',
#        'has_advance_payment', 'status', 'assignment_sale', 'is_placement_paid',
#        'discount_status.status', 'discount_status.value', 'address.id',
#        'address.kind', 'address.guid', 'address.parent_id',
#        'address.locality.id', 'address.locality.kind',
#        'address.locality.subkind', 'address.locality.parent_id',
#        'house.floors'],
#       dtype='object')

# %% [markdown]
# *Обозначения колонок*

# %% [markdown]
# Колонка  | Значение
# ---------|------------
# offer_type | продажа или аренда
# object_info.floor | этаж квартиры
# object_info.rooms| кол-во комнат
# object_info.area| площадь квартиры
# price_info.price| цена квартиры
# price_info.square_price| цена за квадратный метр
# address.position.lat| географическая широта
# address.position.lon| географическая долгота
# seller.agent.is_agent| является ли продавец агентом
# published_dt| дата публикации
# updated_dt| дата последнего обновления
# trade_in| возможность обмена
# source| источник объявления(?)
# ipoteka_rate| процент по ипотеке
# has_advance_payment| есть ли авансовый платёж
# status| текущий статус объявления
# assignment_sale| продажа по уступке прав
# is_placement_paid| оплачено ли размещение
# discount_status.status| статус скидки
# discount_status.value| размер скидки
# address.id| идентификатор адреса
# address.kind| тип адреса (улица, проспект и т.д.)
# address.guid| уникальный идентификатор адреса
# address.parent_id| идентификатор родительского объекта (район)
# address.locality.id| идентификатор населенного пункта
# address.locality.kind| тип населенного пункта (город, поселок и т.д.)
# address.locality.subkind| подтип населенного пункта
# address.locality.parent_id| идентификатор родительского населенного пункта
# house.floors| кол-во этажей в доме

# %%
# визуализация пропусков
plt.figure(figsize=(15, 10))
sns.heatmap(df.isnull(),cmap='PuRd')
# Out:
# <Axes: >

# %% [markdown]
# Много пропусков в "discount_status.value", дропаем эту колонку и "discount_status.status" вместе с ней

# %%
df.drop(['discount_status.value', 'discount_status.status'], axis=1,inplace=True)

# %%
# визуализация пропусков
plt.figure(figsize=(10, 8))
sns.heatmap(df.isnull(),cmap='PuRd_r')
# Out:
# <Axes: >

# %% [markdown]
# Смотрим сколько пропусков в каждой колонке

# %%
null_counts = df.isnull().sum().reset_index()
null_counts.columns = ['Column', 'Null Count']

print(null_counts)
# Out:
#                         Column  Null Count
# 0                   offer_type           0
# 1            object_info.floor        2493
# 2            object_info.rooms           0
# 3             object_info.area           0
# 4             price_info.price           0
# 5      price_info.square_price           0
# 6         address.position.lat           0
# 7         address.position.lon           0
# 8        seller.agent.is_agent        2493
# 9                 published_dt           0
# 10                  updated_dt        2493
# 11                    trade_in           0
# 12                      source           0
# 13                ipoteka_rate        2493
# 14         has_advance_payment        2493
# 15                      status           0
# 16             assignment_sale        2493
# 17           is_placement_paid        2493
# 18                  address.id           0
# 19                address.kind           0
# 20                address.guid           0
# 21           address.parent_id        2875
# 22         address.locality.id           0
# 23       address.locality.kind           0
# 24    address.locality.subkind         951
# 25  address.locality.parent_id        2498
# 26                house.floors           0

# %% [markdown]
# Этаж квартиры отсутствует в 2493 строчках, дропаем их, так как это довольно важный параметр для формирования стоимости квартиры

# %%
df = df.dropna(subset=['object_info.floor'])

# %%
null_counts = df.isnull().sum().reset_index()
null_counts.columns = ['Column', 'Null Count']

print(null_counts)
# Out:
#                         Column  Null Count
# 0                   offer_type           0
# 1            object_info.floor           0
# 2            object_info.rooms           0
# 3             object_info.area           0
# 4             price_info.price           0
# 5      price_info.square_price           0
# 6         address.position.lat           0
# 7         address.position.lon           0
# 8        seller.agent.is_agent           0
# 9                 published_dt           0
# 10                  updated_dt           0
# 11                    trade_in           0
# 12                      source           0
# 13                ipoteka_rate           0
# 14         has_advance_payment           0
# 15                      status           0
# 16             assignment_sale           0
# 17           is_placement_paid           0
# 18                  address.id           0
# 19                address.kind           0
# 20                address.guid           0
# 21           address.parent_id         382
# 22         address.locality.id           0
# 23       address.locality.kind           0
# 24    address.locality.subkind         951
# 25  address.locality.parent_id           5
# 26                house.floors           0

# %% [markdown]
# Снова смотрим пропуски по всем столбцам, нулевые значения удалились в других колонках тоже, где было такое же количество пропусков

# %% [markdown]
# Выводим уникальные значения по всем колонкам, связанным с адресом, чтобы понять какие данные в них записаны

# %%
print(f'address.id: {df["address.id"].unique()}\n{"-"*100}\naddress.kind: {df["address.kind"].unique()}\n{"-"*100}\naddress.guid: {df["address.guid"].unique()}\n{"-"*100}\naddress.parent_id: {df["address.parent_id"].unique()}\n{"-"*100}\naddress.locality.id: {df["address.locality.id"].unique()}\n{"-"*100}\naddress.locality.kind: {df["address.locality.kind"].unique()}\n{"-"*100}\naddress.locality.subkind: {df["address.locality.subkind"].unique()}\n{"-"*100}\naddress.locality.parent_id: {df["address.locality.parent_id"].unique()}')
# Out:
# address.id: [  4300767   3591895   4301456 ...   9082668  55567623 302178733]
# ----------------------------------------------------------------------------------------------------
# address.kind: ['house' 'district' 'street' 'locality']
# ----------------------------------------------------------------------------------------------------
# address.guid: ['4181d7df-0756-4b6a-ba72-ccf79fd9d17f'
#  '252b2fd6-fb82-465b-bc77-1991a5692dcd'
#  'e9ca0770-5627-4371-8e6a-b2472d9b5ec3' ...
#  '5ea6f09c-0d97-4c48-b1da-ccf029b608f6'
#  '3a2069d6-407c-4622-89e3-ad4bdc8f09eb'
#  '8bf0851c-5ade-4879-83ec-9506fc4cfa3d']
# ----------------------------------------------------------------------------------------------------
# address.parent_id: [1.26020000e+06 7.51410000e+04 3.00075664e+08 ... 4.82485660e+07
#  2.82081440e+07 5.55676220e+07]
# ----------------------------------------------------------------------------------------------------
# address.locality.id: [     2299 300001986  54929532      2444      2442      3993  54934713
#   54936219 300004930      6751 300015134 300001508  56014472     73525
#   54596556    527625  23134712  56024978    109452    135849 300012555
#  300015441 300004276 300003194 300007133  54918107     32251  54961468
#   54943012  36184997    464731   1288004 300002038 300005644  54945969
#      24623 300004965  54949441  54937684 300005987  54605882 300014237
#   54944664  56017751   3611799   1178811   5362705     73603 300007111
#  300014471 300079756   1225115 300027495  54938702 300075792 300033255
#  300008434     88743  40147727  56038131 300074639      2477   5435268
#     214923     18515  56032758    215709  54921882    114367 300041012
#  300008400   3530891  54964030 300117008   4803748 300076177  54937061
#  300023126 300006217  56064321    214591  54993949]
# ----------------------------------------------------------------------------------------------------
# address.locality.kind: ['province' 'locality']
# ----------------------------------------------------------------------------------------------------
# address.locality.subkind: ['region' nan]
# ----------------------------------------------------------------------------------------------------
# address.locality.parent_id: [5.4100000e+02 2.2990000e+03 5.4785642e+07 2.4380000e+03 2.4340000e+03
#  5.4923644e+07 5.4596555e+07           nan 6.6550000e+03 5.4917822e+07
#  3.2248000e+04 5.4432095e+07 2.3125892e+07 2.4232749e+07 7.3518000e+04
#  2.4619000e+04 2.3359607e+07 2.9844000e+04 2.8645000e+04 2.1138200e+05
#  6.7460000e+03 2.3230709e+07 8.8742000e+04 2.3126032e+07 1.8511000e+04
#  5.4921881e+07 1.4198700e+05 1.1436600e+05 2.3241146e+07 2.3649087e+07]

# %% [markdown]
# Удаляем оставшиеся нулевые значения, так как их нельзя заполнить каким-либо способом

# %%
df = df.dropna(subset=['address.parent_id', 'address.locality.subkind', 'address.locality.parent_id'])

# %%
# визуализация пропусков
plt.figure(figsize=(8, 5))
sns.heatmap(df.isnull(), cmap='PuRd_r')
# Out:
# <Axes: >

# %% [markdown]
# Нулевых значений не осталось

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16270 entries, 0 to 19839
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   offer_type                  16270 non-null  object
#  1   object_info.floor           16270 non-null  float64
#  2   object_info.rooms           16270 non-null  int64
#  3   object_info.area            16270 non-null  float64
#  4   price_info.price            16270 non-null  int64
#  5   price_info.square_price     16270 non-null  int64
#  6   address.position.lat        16270 non-null  float64
#  7   address.position.lon        16270 non-null  float64
#  8   seller.agent.is_agent       16270 non-null  object
#  9   published_dt                16270 non-null  object
#  10  updated_dt                  16270 non-null  object
#  11  trade_in                    16270 non-null  bool
#  12  source                      16270 non-null  object
#  13  ipoteka_rate                16270 non-null  float64
#  14  has_advance_payment         16270 non-null  object
#  15  status                      16270 non-null  int64
#  16  assignment_sale             16270 non-null  object
#  17  is_placement_paid           16270 non-null  object
#  18  address.id                  16270 non-null  int64
#  19  address.kind                16270 non-null  object
#  20  address.guid                16270 non-null  object
#  21  address.parent_id           16270 non-null  float64
#  22  address.locality.id         16270 non-null  int64
#  23  address.locality.kind       16270 non-null  object
#  24  address.locality.subkind    16270 non-null  object
#  25  address.locality.parent_id  16270 non-null  float64
#  26  house.floors                16270 non-null  int64
# dtypes: bool(1), float64(7), int64(7), object(12)
# memory usage: 3.4+ MB

# %% [markdown]
# Ещё раз выводим информацию о датасете. Из 20073 строк осталось 16270, из 40 колонок 27, двенадцать из которых имеют тип данных "object".
#
# Удаляем колонки "address.___" с текстовым типом данных, так как идентификаторов пунктов должно быть достаточно.
#
# + удаляем ненужные колонки: assignment_sale (продажа по уступке прав), is_placement_paid (оплачено ли размещение), source (источник объявления), has_advance_payment (есть ли авансовый платёж), published_dt и updated_dt (даты публикации и обновления), seller.agent.is_agent (агент ли продавец)

# %%
df.drop(['address.locality.subkind', 'address.locality.kind', 'address.guid', 'address.kind', 'assignment_sale', 'is_placement_paid', 'source', 'has_advance_payment', 'published_dt', 'updated_dt', 'seller.agent.is_agent'], axis=1, inplace=True)

# %%
# выводим размер датасета и названия оставшихся колонок
print(df.shape,'\n', df.columns)
# Out:
# (16270, 16)
#  Index(['offer_type', 'object_info.floor', 'object_info.rooms',
#        'object_info.area', 'price_info.price', 'price_info.square_price',
#        'address.position.lat', 'address.position.lon', 'trade_in',
#        'ipoteka_rate', 'status', 'address.id', 'address.parent_id',
#        'address.locality.id', 'address.locality.parent_id', 'house.floors'],
#       dtype='object')

# %% [markdown]
# По итогу осталось 16 колонок

# %%
# выводим все колонки с типом данных "object"
df.columns[df.dtypes == 'object']
# Out:
# Index(['offer_type'], dtype='object')

# %% [markdown]
# Таких колонок всего одна штука, смотрим какие в ней значения

# %%
df['offer_type'].unique()
# Out:
# array(['flat'], dtype=object)

# %% [markdown]
# В колонке одно значение (квартира), пропусков в ней нет, поэтому её тоже можно удалить

# %%
df.drop(['offer_type'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16270 entries, 0 to 19839
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_info.floor           16270 non-null  float64
#  1   object_info.rooms           16270 non-null  int64
#  2   object_info.area            16270 non-null  float64
#  3   price_info.price            16270 non-null  int64
#  4   price_info.square_price     16270 non-null  int64
#  5   address.position.lat        16270 non-null  float64
#  6   address.position.lon        16270 non-null  float64
#  7   trade_in                    16270 non-null  bool
#  8   ipoteka_rate                16270 non-null  float64
#  9   status                      16270 non-null  int64
#  10  address.id                  16270 non-null  int64
#  11  address.parent_id           16270 non-null  float64
#  12  address.locality.id         16270 non-null  int64
#  13  address.locality.parent_id  16270 non-null  float64
#  14  house.floors                16270 non-null  int64
# dtypes: bool(1), float64(7), int64(7)
# memory usage: 1.9 MB

# %% [markdown]
# Колонок с типом данных "object" не осталось, пробуем вывести матрицу корреляции

# %%
plt.figure(figsize = (20, 10))
sns.heatmap(df.corr(), annot = True, cmap = 'PuRd_r')
plt.show()

# %% [markdown]
# Колонки "trade_in", "address.locality.id", "address.locality.parent_id" не коррелируют ни с чем, дропаем их и ещё раз выводим матрицу

# %%
df.drop(['trade_in', 'address.locality.id', 'address.locality.parent_id'], axis=1, inplace=True)

# %%
plt.figure(figsize = (16, 8))
sns.heatmap(df.corr(), annot = True, cmap = 'PuRd')
plt.show()

# %% [markdown]
# Матрица корреляции показывает, что:
#
#
# *   Количество комнат больше всего зависит от площади квартиры
# *   Площадь квартиры зависит от её стоимости и количества комнат
# *   Стоимость квартиры больше зависит от площади и цены за квадратный метр, чем от количества комнат
# *   Цена за квадратный метр зависит от стоимости квартиры и от площади.

# %% [markdown]
# # Циан °˖𓍢ִ໋ 🐟✧°⋆

# %% [markdown]
# ---

# %% [markdown]
# ## Предобработка

# %%
df_c = pd.read_csv('/content/drive/MyDrive/war_is_over.csv', sep = ',')
df_c.head(10)
# Out:
#                               author        author_type  \
# 0                       ID 115709096          homeowner
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                         ID 3246838            realtor
# 3                        ID 64398571            unknown
# 4                          ЛИДЕРМЭЙН  real_estate_agent
# 5                        Максим Юсов  real_estate_agent
# 6                         ID 9655060            unknown
# 7                     Этажи Серпухов  real_estate_agent
# 8                    Ольга Протченко            realtor
# 9                        Глеб Маслов            realtor
#
#                                               url  location deal_type  \
# 0  https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1  https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2  https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3  https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4  https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
# 5  https://serpukhov.cian.ru/sale/flat/304233768/  Серпухов      sale
# 6  https://serpukhov.cian.ru/sale/flat/304697154/  Серпухов      sale
# 7  https://serpukhov.cian.ru/sale/flat/304332318/  Серпухов      sale
# 8  https://serpukhov.cian.ru/sale/flat/295915722/  Серпухов      sale
# 9  https://serpukhov.cian.ru/sale/flat/304548494/  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0               flat     6            6           1         20.7  ...
# 1               flat     1            9           1         33.0  ...
# 2               flat     4            4           1         14.0  ...
# 3               flat     5            5           1         17.5  ...
# 4               flat     4            7           1         25.9  ...
# 5               flat     2            3           1         46.7  ...
# 6               flat     3            5           1         29.0  ...
# 7               flat     3            6           1         19.1  ...
# 8               flat     1            2           1         27.1  ...
# 9               flat     6            9           2         42.7  ...
#
#   finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0          -1         18 м²           1 м²  79175096253            3 м
# 1          -1         18 м²           6 м²  79645530086          2,7 м
# 2          -1            -1             -1  79807126116             -1
# 3          -1            -1             -1  79645652380             -1
# 4          -1         20 м²           5 м²  79099408093          3,5 м
# 5          -1         25 м²           6 м²  79647820594             -1
# 6          -1         25 м²             -1  79645658245            3 м
# 7          -1            -1             -1  79647821411             -1
# 8          -1         18 м²           6 м²  79671343432          2,5 м
# 9          -1       29,7 м²         5,6 м²  79150509841          2,7 м
#
#                   district                street house_number underground  \
# 0                 Серпухов               Крюкова            4         NaN
# 1                      NaN            Ворошилова          144      Аннино
# 2  Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                 Серпухов           Российская            40         NaN
# 4                 Серпухов               Химиков            8         NaN
# 5                 Серпухов        2-я Московская          6к3         NaN
# 6                 Серпухов                Форсса           10         NaN
# 7                 Серпухов               Крюкова            4         NaN
# 8                      NaN                   NaN          NaN         NaN
# 9                 Серпухов             Весенняя            56         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
#
# [10 rows x 27 columns]

# %%
# выводим размер дф
df_c.shape
# Out:
# (8393, 27)

# %%
df_c = df_c.drop_duplicates()

# %%
# выводим размер дф ещё раз
df_c.shape
# Out:
# (7577, 27)

# %% [markdown]
# В дф 7577 строчки и 27 колонок. Первые две колонки сразу удаляем, так как они не нужны для анализа, после чего выводим информацию о датасете

# %%
df_c.drop(['author', 'author_type'], axis=1, inplace=True)

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7577 entries, 0 to 8392
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   7576 non-null   object
#  1   location              7576 non-null   object
#  2   deal_type             7576 non-null   object
#  3   accommodation_type    7576 non-null   object
#  4   floor                 7576 non-null   object
#  5   floors_count          7576 non-null   object
#  6   rooms_count           7576 non-null   object
#  7   total_meters          7576 non-null   object
#  8   price                 7563 non-null   object
#  9   year_of_construction  7576 non-null   object
#  10  object_type           7576 non-null   object
#  11  have_loggia           7576 non-null   object
#  12  parking_type          7576 non-null   object
#  13  house_material_type   7576 non-null   object
#  14  heating_type          7576 non-null   object
#  15  finish_type           7576 non-null   object
#  16  living_meters         7576 non-null   object
#  17  kitchen_meters        7576 non-null   object
#  18  phone                 7576 non-null   object
#  19  ceiling_height        7576 non-null   object
#  20  district              2994 non-null   object
#  21  street                6002 non-null   object
#  22  house_number          6444 non-null   object
#  23  underground           5300 non-null   object
#  24  residential_complex   3799 non-null   object
# dtypes: object(25)
# memory usage: 1.5+ MB

# %% [markdown]
# Все колонки имеют тип данных object 😭

# %% [markdown]
# *Обозначения колонок*

# %% [markdown]
# Колонка  | Значение
# ---------|------------
# url | ссылка
# location | локация объявления (город)
# deal_type| тип объявления (продажа/аренда)
# accommodation_type| тип жилья (квартира, дом и т.д.)
# floor| этаж квартиры
# floors_count| количество этажей
# total_meters| площадь квартиры
# price| общая стоимость
# seller.agent.is_agent| является ли продавец агентом
# year_of_construction| год постройки здания
# object_type|  тип жилья (новостройка\вторичка)
# have_loggia| наличие лоджий\балконов
# house_material_type| тип дома (монолитный, панельный и т.д.)
# heating_type| тип отопления
# finish_type| отделка
# living_meters| жилая площадь
# kitchen_meters| площадь кухни
# phone| номер телефона
# ceiling_height| высота потолка
# district| район
# street| улица
# house_number| номер дома
# underground| метро (+ мцд)
# residential_complex| жилой комплекс

# %% [markdown]
# ---
#
#
# Примечание из документации циан-парсера:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Исходя из этого надо найти по таблице все значения, равные "-1" и заменить их на нулевые

# %%
# выводим сколько нулевых значений есть изначально
null_counts_cian = df_c.isnull().sum().reset_index()
null_counts_cian.columns = ['Column', 'Null Count']

print(null_counts_cian)
# Out:
#                   Column  Null Count
# 0                    url           1
# 1               location           1
# 2              deal_type           1
# 3     accommodation_type           1
# 4                  floor           1
# 5           floors_count           1
# 6            rooms_count           1
# 7           total_meters           1
# 8                  price          14
# 9   year_of_construction           1
# 10           object_type           1
# 11           have_loggia           1
# 12          parking_type           1
# 13   house_material_type           1
# 14          heating_type           1
# 15           finish_type           1
# 16         living_meters           1
# 17        kitchen_meters           1
# 18                 phone           1
# 19        ceiling_height           1
# 20              district        4583
# 21                street        1575
# 22          house_number        1133
# 23           underground        2277
# 24   residential_complex        3778

# %% [markdown]
# *   Есть одна строка, которая везде пустая

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_c.isnull(), cmap='BuPu_r')
# Out:
# <Axes: >

# %%
# "-1" меняем на NaN (нул. знач.)
df_c.replace('-1', np.nan, inplace=True)

df_c.head(10)
# Out:
#                                               url  location deal_type  \
# 0  https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1  https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2  https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3  https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4  https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
# 5  https://serpukhov.cian.ru/sale/flat/304233768/  Серпухов      sale
# 6  https://serpukhov.cian.ru/sale/flat/304697154/  Серпухов      sale
# 7  https://serpukhov.cian.ru/sale/flat/304332318/  Серпухов      sale
# 8  https://serpukhov.cian.ru/sale/flat/295915722/  Серпухов      sale
# 9  https://serpukhov.cian.ru/sale/flat/304548494/  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters    price  \
# 0               flat     6            6           1         20.7  2350000
# 1               flat     1            9           1         33.0  4150000
# 2               flat     4            4           1         14.0  1700000
# 3               flat     5            5           1         17.5  2500000
# 4               flat     4            7           1         25.9  3000000
# 5               flat     2            3           1         46.7  6599999
# 6               flat     3            5           1         29.0  3350000
# 7               flat     3            6           1         19.1  3600000
# 8               flat     1            2           1         27.1  1900000
# 9               flat     6            9           2         42.7  3990000
#
#   year_of_construction  ... finish_type living_meters kitchen_meters  \
# 0                 1917  ...         NaN         18 м²           1 м²
# 1                 1975  ...         NaN         18 м²           6 м²
# 2                  NaN  ...         NaN           NaN            NaN
# 3                 1968  ...         NaN           NaN            NaN
# 4                 2009  ...         NaN         20 м²           5 м²
# 5                  NaN  ...         NaN         25 м²           6 м²
# 6                 1917  ...         NaN         25 м²            NaN
# 7                 1917  ...         NaN           NaN            NaN
# 8                 1969  ...         NaN         18 м²           6 м²
# 9                 1980  ...         NaN       29,7 м²         5,6 м²
#
#          phone ceiling_height                 district                street  \
# 0  79175096253            3 м                 Серпухов               Крюкова
# 1  79645530086          2,7 м                      NaN            Ворошилова
# 2  79807126116            NaN  Красный Текстильщик мкр   Красный Текстильщик
# 3  79645652380            NaN                 Серпухов           Российская
# 4  79099408093          3,5 м                 Серпухов               Химиков
# 5  79647820594            NaN                 Серпухов        2-я Московская
# 6  79645658245            3 м                 Серпухов                Форсса
# 7  79647821411            NaN                 Серпухов               Крюкова
# 8  79671343432          2,5 м                      NaN                   NaN
# 9  79150509841          2,7 м                 Серпухов             Весенняя
#
#   house_number underground residential_complex
# 0            4         NaN                 NaN
# 1          144      Аннино                 NaN
# 2            2         NaN                 NaN
# 3           40         NaN                 NaN
# 4            8         NaN                 NaN
# 5          6к3         NaN                 NaN
# 6           10         NaN                 NaN
# 7            4         NaN                 NaN
# 8          NaN         NaN                 NaN
# 9           56         NaN                 NaN
#
# [10 rows x 25 columns]

# %%
# выводим кол-во нул. значений ещё раз
null_counts_cian = df_c.isnull().sum().reset_index()
null_counts_cian.columns = ['Column', 'Null Count']

print(null_counts_cian)
# Out:
#                   Column  Null Count
# 0                    url           1
# 1               location           1
# 2              deal_type           1
# 3     accommodation_type           1
# 4                  floor           1
# 5           floors_count           1
# 6            rooms_count          97
# 7           total_meters           1
# 8                  price          14
# 9   year_of_construction        1315
# 10           object_type           1
# 11           have_loggia        3243
# 12          parking_type        3334
# 13   house_material_type        6191
# 14          heating_type        7576
# 15           finish_type        5668
# 16         living_meters        1701
# 17        kitchen_meters        1277
# 18                 phone           1
# 19        ceiling_height        2664
# 20              district        4583
# 21                street        1575
# 22          house_number        1133
# 23           underground        2277
# 24   residential_complex        3778

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_c.isnull(), cmap='BuPu_r')
# Out:
# <Axes: >

# %% [markdown]
# Пропусков стало намного больше. Полностью удаляем колонки "heating_type", "house_material_type", "finish_type" и 'district', т.к. в них очень много пропусков. Так же удаляем строчки, в которых не указаны атрибуты "rooms_count" и "url".
# Ещё удаляем колонки "house_number" и "residential_complex", из адреса (местоположения) оставляем метро\мцд и улицу.
#
# Удаляем колонку с номером телефона, т.к. она не нужна для анализа

# %%
# дроп колонок
df_c.drop(['heating_type', 'house_material_type', 'house_number', 'residential_complex', 'phone', 'district', 'finish_type'], axis=1,inplace=True)
# дроп строчек
df_c = df_c.dropna(subset=['url', 'rooms_count'])

# %% [markdown]
# Попробуем вывести информацию о том, какие значения есть в колонке "url"

# %%
df_c[['url']].describe()
# Out:
#                                              url
# count                                       7480
# unique                                      6636
# top     https://www.cian.ru/sale/flat/308553708/
# freq                                           6

# %% [markdown]
# Уникальных значений в колонке "url" меньше, чем строк (самих ссылок). Оставляем только уникальные значения

# %%
df_c = df_c.drop_duplicates(subset=['url'], keep='first')
print(df_c.shape)
# Out:
# (6636, 18)

# %% [markdown]
# Заменим пропуски в колонках "have_loggia", "parking_type" на "0", то есть укажем, что парковки/балконов просто нет

# %%
df_c['have_loggia'] = df_c['have_loggia'].fillna('0')
df_c['parking_type'] = df_c['parking_type'].fillna('0')

# %% [markdown]
# ---
#
#
# Визуализация пропусков

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(df_c.isnull(), cmap='BuPu_r')
# Out:
# <Axes: >

# %%
# выводим кол-во пропусков
null_counts_cian = df_c.isnull().sum().reset_index()
null_counts_cian.columns = ['Column', 'Null Count']

print(null_counts_cian)
# Out:
#                   Column  Null Count
# 0                    url           0
# 1               location           0
# 2              deal_type           0
# 3     accommodation_type           0
# 4                  floor           0
# 5           floors_count           0
# 6            rooms_count           0
# 7           total_meters           0
# 8                  price          11
# 9   year_of_construction        1120
# 10           object_type           0
# 11           have_loggia           0
# 12          parking_type           0
# 13         living_meters        1466
# 14        kitchen_meters        1088
# 15        ceiling_height        2315
# 16                street        1396
# 17           underground        1988

# %% [markdown]
# Заполняем пропуски в колонке "price": Выводим ссылки и вручную меняем значение в ячейке на стоимость

# %%
# берём из дф строчки, где по колонке price нул. значения, сохраняем их
#в новую переменную (тип: дф) и выводим только url
nul_price = df_c[df_c['price'].isnull() == True]
nul_price['url']
# Out:
# 115           https://www.cian.ru/sale/flat/306610279/
# 499     https://odintsovo.cian.ru/sale/flat/308938596/
# 579           https://www.cian.ru/sale/flat/306610643/
# 598           https://spb.cian.ru/sale/flat/301311394/
# 927           https://www.cian.ru/sale/flat/306611541/
# 1040          https://www.cian.ru/sale/flat/308752150/
# 1103          https://www.cian.ru/sale/flat/272333560/
# 3027          https://www.cian.ru/sale/flat/308960138/
# 3053          https://www.cian.ru/sale/flat/306611693/
# 3498    https://odintsovo.cian.ru/sale/flat/308938542/
# 5842          https://www.cian.ru/sale/flat/306610990/
# Name: url, dtype: object

# %%
df_nul_price = df_c.loc[df_c['price'].isna()]
df_nul_price
# Out:
#                                                  url    location deal_type  \
# 115         https://www.cian.ru/sale/flat/306610279/      Москва      sale
# 499   https://odintsovo.cian.ru/sale/flat/308938596/    Одинцово      sale
# 579         https://www.cian.ru/sale/flat/306610643/  Ивантеевка      sale
# 598         https://spb.cian.ru/sale/flat/301311394/  Ивантеевка      sale
# 927         https://www.cian.ru/sale/flat/306611541/      Москва      sale
# 1040        https://www.cian.ru/sale/flat/308752150/      Москва      sale
# 1103        https://www.cian.ru/sale/flat/272333560/      Москва      sale
# 3027        https://www.cian.ru/sale/flat/308960138/      Москва      sale
# 3053        https://www.cian.ru/sale/flat/306611693/      Москва      sale
# 3498  https://odintsovo.cian.ru/sale/flat/308938542/    Одинцово      sale
# 5842        https://www.cian.ru/sale/flat/306610990/      Москва      sale
#
#      accommodation_type floor floors_count rooms_count total_meters price  \
# 115                flat     8           59           3         56.1   NaN
# 499                flat     2           24           1         36.3   NaN
# 579                flat     2           59           2         31.1   NaN
# 598                flat     9           12           3        115.1   NaN
# 927                flat     2           59           1         30.4   NaN
# 1040               flat    14           21           1        38.93   NaN
# 1103               flat    11           21           3         74.5   NaN
# 3027               flat    16           47           4         80.3   NaN
# 3053               flat     2           59           4         94.9   NaN
# 3498               flat     2           24           4        82.78   NaN
# 5842               flat     6           59           5        103.9   NaN
#
#      year_of_construction                object_type have_loggia parking_type  \
# 115                  2028                Новостройка           0            0
# 499                  2025                Новостройка           0    Подземная
# 579                  2028                Новостройка           0            0
# 598                  2023                Новостройка           0            0
# 927                  2028                Новостройка           0            0
# 1040                 2026                Новостройка           0    Подземная
# 1103                 2020  Новостройка / Апартаменты           0            0
# 3027                 2027                Новостройка           0    Подземная
# 3053                 2028                Новостройка           0            0
# 3498                 2025                Новостройка           0    Подземная
# 5842                 2028                Новостройка           0            0
#
#      living_meters kitchen_meters ceiling_height             street  \
# 115        36,1 м²            NaN         2,85 м                NaN
# 499        21,8 м²            NaN          2,8 м                NaN
# 579        15,7 м²            NaN         2,85 м                NaN
# 598        48,4 м²          28 м²         2,85 м    Белоостровская
# 927         9,7 м²            NaN         2,85 м                NaN
# 1040           NaN            NaN         2,85 м        Северный ао
# 1103       46,9 м²         7,8 м²          3,3 м  Аминьевское шоссе
# 3027       33,6 м²        27,6 м²         2,68 м                NaN
# 3053       54,6 м²            NaN         2,85 м                NaN
# 3498       49,7 м²            NaN          2,8 м                NaN
# 5842       65,7 м²            NaN         2,85 м                NaN
#
#       underground
# 115     Давыдково
# 499      Одинцово
# 579     Давыдково
# 598        Лесная
# 927     Давыдково
# 1040  Селигерская
# 1103    Давыдково
# 3027  Кожуховская
# 3053    Давыдково
# 3498     Одинцово
# 5842    Давыдково

# %%
# удаляем 598-ую строчку тк там СПБ
df_c.drop(598, inplace=True)
# остальные строчки заполняем
df_c.loc[115, 'price'] = '24276097'
df_c.loc[499, 'price'] = '8348901'
df_c.loc[579, 'price'] = '15456451'
df_c.loc[927, 'price'] = '14475264'
df_c.loc[1040, 'price'] = '15734509'
df_c.loc[1103, 'price'] = '22984089'
df_c.loc[3027, 'price'] = '39335873'
df_c.loc[3053, 'price'] = '34958598'
df_c.loc[3498, 'price'] = '17531381'
df_c.loc[5842, 'price'] = '36727923'

# %%
plt.figure(figsize=(6, 3))
sns.heatmap(df_c.isnull(), cmap='Pastel1_r')
# Out:
# <Axes: >

# %%
# удаляем колонку с адресом, она больше не нужна
df_c.drop(['url'], axis=1,inplace=True)

# %% [markdown]
# Смотрим на значения колонок "deal_type" и "accommodation_type"

# %%
print(df_c['deal_type'].unique())
print(df_c['accommodation_type'].unique())
# Out:
# ['sale' 'deal_type']
# ['flat' 'accommodation_type']

# %%
# удаляем их, тк они содержат одно значение и ни на что не влияют
df_c.drop(['deal_type', 'accommodation_type'], axis=1,inplace=True)

# %% [markdown]
# ## Кодирование + обработка нул. значений(?)

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6635 entries, 0 to 8392
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              6635 non-null   object
#  1   floor                 6635 non-null   object
#  2   floors_count          6635 non-null   object
#  3   rooms_count           6635 non-null   object
#  4   total_meters          6635 non-null   object
#  5   price                 6635 non-null   object
#  6   year_of_construction  5515 non-null   object
#  7   object_type           6635 non-null   object
#  8   have_loggia           6635 non-null   object
#  9   parking_type          6635 non-null   object
#  10  living_meters         5169 non-null   object
#  11  kitchen_meters        5547 non-null   object
#  12  ceiling_height        4320 non-null   object
#  13  street                5239 non-null   object
#  14  underground           4647 non-null   object
# dtypes: object(15)
# memory usage: 1.1+ MB

# %% [markdown]
# ---
#
#
# Меняем тип данных у колонок, которые хранят численные данные

# %% [markdown]
# ---
#
# * rooms_count

# %%
# выводим уник. значения
df_c['rooms_count'].unique()
# Out:
# array(['1', '2', '3', '4', '5', 'rooms_count'], dtype=object)

# %%
# rooms_count странное значение, выводим все строчки с ним
df_st_rooms = df_c.loc[df_c['rooms_count'] == 'rooms_count']
df_st_rooms
# Out:
#       location  floor  floors_count  rooms_count  total_meters  price  \
# 4346  location  floor  floors_count  rooms_count  total_meters  price
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 4346  year_of_construction  object_type  have_loggia  parking_type
#
#       living_meters  kitchen_meters  ceiling_height  street  underground
# 4346  living_meters  kitchen_meters  ceiling_height  street  underground

# %%
# удаляем эту строчку
df_c.drop(4346, inplace=True)

# %%
# меняем тип данных
df_c['rooms_count'] = pd.to_numeric(df_c['rooms_count'], errors='raise')
df_c['rooms_count']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8388    2
# 8389    2
# 8390    2
# 8391    2
# 8392    2
# Name: rooms_count, Length: 6634, dtype: int64

# %% [markdown]
# ---
#
#
#
# *   Price

# %%
df_c['price'] = pd.to_numeric(df_c['price'], errors='raise')
# изменяем флот на инт
df_c['price'] = df_c['price'].astype(int)
df_c['price']
# Out:
# 0        2350000
# 1        4150000
# 2        1700000
# 3        2500000
# 4        3000000
#           ...
# 8388    11400000
# 8389     8607014
# 8390     7300000
# 8391     6400000
# 8392    13014356
# Name: price, Length: 6634, dtype: int64

# %% [markdown]
# ---
#
#
#
# *   floor и floors_count

# %%
# floor
df_c['floor'] = pd.to_numeric(df_c['floor'], errors ='raise')
df_c['floor']
# Out:
# 0        6
# 1        1
# 2        4
# 3        5
# 4        4
#         ..
# 8388     8
# 8389    19
# 8390     3
# 8391     3
# 8392     3
# Name: floor, Length: 6634, dtype: int64

# %%
# floors_count
df_c['floors_count'] = pd.to_numeric(df_c['floors_count'], errors ='raise')
df_c['floors_count']
# Out:
# 0        6
# 1        9
# 2        4
# 3        5
# 4        7
#         ..
# 8388    14
# 8389    25
# 8390     5
# 8391     6
# 8392    16
# Name: floors_count, Length: 6634, dtype: int64

# %% [markdown]
# ---
#
#
#
#
#
# * total_meters

# %%
df_c['total_meters'].unique()
# Out:
# array(['20.7', '33.0', '14.0', ..., '30.47', '36.79', '48.39'],
#       dtype=object)

# %%
df_c['total_meters'] = pd.to_numeric(df_c['total_meters'], errors ='raise')
df_c['total_meters']
# Out:
# 0       20.7
# 1       33.0
# 2       14.0
# 3       17.5
# 4       25.9
#         ...
# 8388    69.7
# 8389    48.1
# 8390    45.0
# 8391    34.0
# 8392    58.6
# Name: total_meters, Length: 6634, dtype: float64

# %% [markdown]
# ---
#
# Снова выводим информацию про дф

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6634 entries, 0 to 8392
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              6634 non-null   object
#  1   floor                 6634 non-null   int64
#  2   floors_count          6634 non-null   int64
#  3   rooms_count           6634 non-null   int64
#  4   total_meters          6634 non-null   float64
#  5   price                 6634 non-null   int64
#  6   year_of_construction  5514 non-null   object
#  7   object_type           6634 non-null   object
#  8   have_loggia           6634 non-null   object
#  9   parking_type          6634 non-null   object
#  10  living_meters         5168 non-null   object
#  11  kitchen_meters        5546 non-null   object
#  12  ceiling_height        4319 non-null   object
#  13  street                5238 non-null   object
#  14  underground           4646 non-null   object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 829.2+ KB

# %% [markdown]
# ---
# * ceiling_height

# %%
df_c['ceiling_height'].unique()
# Out:
# array(['3\xa0м', '2,7\xa0м', nan, '3,5\xa0м', '2,5\xa0м', '2,8\xa0м',
#        '2,4\xa0м', '2,6\xa0м', '2,65\xa0м', '2,73\xa0м', '4,6\xa0м',
#        '3,25\xa0м', '2,85\xa0м', '3,2\xa0м', '2,64\xa0м', '3,6\xa0м',
#        '3,06\xa0м', '3,1\xa0м', '3,15\xa0м', '3,35\xa0м', '2,92\xa0м',
#        '3,12\xa0м', '5\xa0м', '3,3\xa0м', '2,87\xa0м', '2,95\xa0м',
#        '2,9\xa0м', '2,82\xa0м', '2,99\xa0м', '3,08\xa0м', '3,4\xa0м',
#        '3,27\xa0м', '2,75\xa0м', '3,9\xa0м', '6\xa0м', '3,43\xa0м',
#        '2,51\xa0м', '3,05\xa0м', '2,78\xa0м', '5,2\xa0м', '2,72\xa0м',
#        '2,63\xa0м', '2,62\xa0м', '2,89\xa0м', '2,68\xa0м', '2,66\xa0м',
#        '3,09\xa0м', '2,55\xa0м', '2,84\xa0м', '2,48\xa0м', '4\xa0м',
#        '2,67\xa0м', '2,74\xa0м', '3,59\xa0м', '3,04\xa0м', '2,56\xa0м',
#        '2\xa0м', '2,42\xa0м', '3,02\xa0м', '3,26\xa0м', '4,5\xa0м',
#        '5,7\xa0м', '3,23\xa0м', '3,14\xa0м', '3,65\xa0м', '3,03\xa0м',
#        '3,24\xa0м', '2,77\xa0м', '4,2\xa0м', '3,55\xa0м', '2,57\xa0м',
#        '3,31\xa0м', '3,52\xa0м', '1,8\xa0м', '3,74\xa0м', '2,52\xa0м',
#        '2,69\xa0м', '3,75\xa0м', '2,54\xa0м', '2,76\xa0м', '3,45\xa0м',
#        '2,88\xa0м', '2,53\xa0м', '2,83\xa0м', '4,4\xa0м', '2,58\xa0м',
#        '52\xa0м', '2,26\xa0м', '2,3\xa0м', '1,65\xa0м', '3,17\xa0м',
#        '2,98\xa0м', '3,72\xa0м', '2,97\xa0м', '3,01\xa0м', '2,71\xa0м',
#        '0\xa0м', '2,7800000000000002\xa0м', '3,36\xa0м', '3,7\xa0м',
#        '25\xa0м', '9\xa0м', '3,34\xa0м', '5,5\xa0м', '5,1\xa0м',
#        '4,55\xa0м', '2,61\xa0м', '2,81\xa0м', '2,2\xa0м'], dtype=object)

# %%
df_c['ceiling_height'] = df_c['ceiling_height'].str.replace(r'\xa0м', '', regex=True).str.replace(',', '.')
df_c['ceiling_height'] = df_c['ceiling_height'].astype(float)
df_c['ceiling_height']
# Out:
# 0       3.00
# 1       2.70
# 2        NaN
# 3        NaN
# 4       3.50
#         ...
# 8388     NaN
# 8389    2.62
# 8390     NaN
# 8391    2.75
# 8392    2.62
# Name: ceiling_height, Length: 6634, dtype: float64

# %% [markdown]
# ---
#
# Снова пропуски:

# %%
plt.figure(figsize=(6, 3))
sns.heatmap(df_c.isnull(), cmap='BuPu')
# Out:
# <Axes: >

# %% [markdown]
# Пробуем заполнить пропуски в колонке "ceiling_height"

# %%
# распределение значений (?)
df_c['ceiling_height'].describe()
# Out:
# count    4319.000000
# mean        2.830968
# std         0.875777
# min         0.000000
# 25%         2.700000
# 50%         2.750000
# 75%         2.900000
# max        52.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Максимальное значение слишком большое для высоты потолка, минимальное тоже невозможно

# %%
sns.boxplot(x='price', y='ceiling_height', data=df_c)
# Out:
# <Axes: xlabel='price', ylabel='ceiling_height'>

# %% [markdown]
# Два выброса, один 52 метра в высоту, второй между 20 и 30

# %%
# выводим два макс. значения
df_c.loc[df_c['ceiling_height'].nlargest(2).index]
# Out:
#       location  floor  floors_count  rooms_count  total_meters    price  \
# 2250  Балашиха      1             2            2          58.3  5700000
# 5121      Клин      5             5            1          31.9  3850000
#
#      year_of_construction object_type have_loggia parking_type living_meters  \
# 2250                 1955    Вторичка           0            0         40 м²
# 5121                 1995    Вторичка    1 балкон     Наземная       17,7 м²
#
#      kitchen_meters  ceiling_height             street      underground
# 2250           6 м²            52.0   Маршала Говорова  Железнодорожная
# 5121         5,3 м²            25.0            Лесная               NaN

# %% [markdown]
# Смотрим на колонку "ceiling_height". Значения совпадают с тем, что изображено на боксплоте.
# Удаляем эти строки

# %%
# выводим 4 минимальных значения. Первую строчку дропаем, остальные оставляем
df_c.loc[df_c['ceiling_height'].nsmallest(4).index]
# Out:
#         location  floor  floors_count  rooms_count  total_meters     price  \
# 3955  Котельники      2             5            2         47.59  12611350
# 2649    Балашиха     13            15            3         73.60  11300000
# 1244    Балашиха      2             5            1         30.70   4300000
# 731       Москва      3            12            2         37.00   9500000
#
#      year_of_construction  object_type have_loggia parking_type living_meters  \
# 3955                 2027  Новостройка           0            0       22,2 м²
# 2649                 1999     Вторичка    3 лоджии     Наземная       40,7 м²
# 1244                 1961     Вторичка           0            0       18,6 м²
# 731                   NaN     Вторичка    1 балкон     Открытая         26 м²
#
#      kitchen_meters  ceiling_height             street      underground
# 3955        12,7 м²            0.00     Комсомольская               NaN
# 2649         8,4 м²            1.65        Октябрьская  Железнодорожная
# 1244         5,3 м²            1.80          Парковая      Салтыковская
# 731            6 м²            2.00  Коровинское шоссе      Селигерская

# %%
df_c.drop(2250, inplace=True)
df_c.drop(5121, inplace=True)
df_c.drop(2027, inplace=True)

# %%
df_c['ceiling_height'].describe()
# Out:
# count    4317.000000
# mean        2.814443
# std         0.305040
# min         0.000000
# 25%         2.700000
# 50%         2.750000
# 75%         2.900000
# max         9.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Заполняем пропуски по колонке средним значением (mean) и округляем до сотых

# %%
df_c['ceiling_height'] = df_c['ceiling_height'].fillna(df_c['ceiling_height'].mean()).round(2)
df_c
# Out:
#       location  floor  floors_count  rooms_count  total_meters     price  \
# 0     Серпухов      6             6            1          20.7   2350000
# 1     Серпухов      1             9            1          33.0   4150000
# 2     Серпухов      4             4            1          14.0   1700000
# 3     Серпухов      5             5            1          17.5   2500000
# 4     Серпухов      4             7            1          25.9   3000000
# ...        ...    ...           ...          ...           ...       ...
# 8388    Мытищи      8            14            2          69.7  11400000
# 8389    Мытищи     19            25            2          48.1   8607014
# 8390    Мытищи      3             5            2          45.0   7300000
# 8391    Мытищи      3             6            2          34.0   6400000
# 8392    Мытищи      3            16            2          58.6  13014356
#
#      year_of_construction  object_type have_loggia parking_type living_meters  \
# 0                    1917     Вторичка           0     Наземная         18 м²
# 1                    1975     Вторичка           0            0         18 м²
# 2                     NaN     Вторичка           0            0           NaN
# 3                    1968     Вторичка           0            0           NaN
# 4                    2009     Вторичка           0     Наземная         20 м²
# ...                   ...          ...         ...          ...           ...
# 8388                 2018     Вторичка           0            0         38 м²
# 8389                 2025  Новостройка           0     Открытая       22,7 м²
# 8390                 1968     Вторичка    1 балкон            0           NaN
# 8391                 2023     Вторичка    1 балкон     Открытая         19 м²
# 8392                 2025  Новостройка           0     Открытая       24,9 м²
#
#      kitchen_meters  ceiling_height                street underground
# 0              1 м²            3.00               Крюкова         NaN
# 1              6 м²            2.70            Ворошилова      Аннино
# 2               NaN            2.81   Красный Текстильщик         NaN
# 3               NaN            2.81           Российская          NaN
# 4              5 м²            3.50               Химиков         NaN
# ...             ...             ...                   ...         ...
# 8388        10,5 м²            2.81            Юбилейная   Медведково
# 8389        16,1 м²            2.62                   NaN   Ростокино
# 8390           6 м²            2.81            Юбилейная   Медведково
# 8391           8 м²            2.75      бульвар Тенистый  Медведково
# 8392        21,4 м²            2.62                   NaN  Медведково
#
# [6631 rows x 15 columns]

# %% [markdown]
# Смотрим на пропуски

# %%
plt.figure(figsize=(6, 3))
sns.heatmap(df_c.isnull(), cmap='Pastel1')
# Out:
# <Axes: >

# %% [markdown]
# ---
#
# * object_type

# %%
print(f'Уникальные значения: {df_c["object_type"].unique()}')
# Out:
# Уникальные значения: ['Вторичка' 'Новостройка' 'Вторичка / Апартаменты'
#  'Новостройка / Апартаменты' 'Вторичка / Пентхаус'
#  'Новостройка / Пентхаус']

# %% [markdown]
# Делаем так, чтобы было всего два варианта: новостройка и вторичка

# %%
# функция для замены значений
def values(value):
  if value == 'Вторичка / Апартаменты':
    return 'Вторичка'
  elif value == 'Вторичка / Пентхаус':
    return 'Вторичка'
  elif value == 'Новостройка / Пентхаус':
    return 'Новостройка'
  elif value == 'Новостройка / Апартаменты':
    return 'Новостройка'
  else:
    return value

df_c['object_type'] = df_c['object_type'].apply(values)

print(f'Уникальные значения: {df_c["object_type"].unique()}')
# Out:
# Уникальные значения: ['Вторичка' 'Новостройка']

# %%
df_c['object_type'] = df_c['object_type'].map(dict(Вторичка = 1, Новостройка = 0))
df_c['object_type']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8388    1
# 8389    0
# 8390    1
# 8391    1
# 8392    0
# Name: object_type, Length: 6631, dtype: int64

# %% [markdown]
# ---
#
#
#
# *   year_of_construction

# %%
# выводим уник. знач.
df_c['year_of_construction'].unique()
# Out:
# array(['1917', '1975', nan, '1968', '2009', '1969', '1980', '1990',
#        '2025', '2015', '1970', '1984', '1965', '2010', '1964', 'Аукцион',
#        '1992', '2011', '1986', '1994', '1956', '1966', '1973', '1971',
#        '1957', '2013', '1981', '1972', '1959', '2004', '1962', '2019',
#        '1978', '1977', '2003', '1963', '1952', '2024', '2007', '1995',
#        '1976', '1982', '1953', '2008', '2026', '2023', '1941', '2028',
#        '1993', '2016', '2027', '2017', '2022', '1932', '2012', '1960',
#        '2006', '1926', '2020', '1943', '2014', '2021', '1967', '1904',
#        '1991', '2018', '1987', '1988', '1974', 'Напишите автору', '1979',
#        '1989', '1985', '1930', '2005', '1958', '1996', '1940', '1948',
#        '1961', '1938', '1997', '2002', '2001', '1999', '1983', '1998',
#        '1902', '2000', '1915', '1910', '1939', '1929', '1954', '1897',
#        '1900', 'Позвоните автору', '1955', '1949', '1947', '1901', '1909',
#        '1600', '1951', '1936', '1931', '1950', '1934', '1928', '1945',
#        '1937', '1927', '1896', '1777', '2031', '1935'], dtype=object)

# %% [markdown]
# Дропаем строки с некорректными данными

# %%
values_to_filter = ['Аукцион', 'Напишите автору', 'Позвоните автору']
maska = df_c['year_of_construction'].isin(values_to_filter)

df_c = df_c[~maska]

df_c['year_of_construction'].unique()
# Out:
# array(['1917', '1975', nan, '1968', '2009', '1969', '1980', '1990',
#        '2025', '2015', '1970', '1984', '1965', '2010', '1964', '1992',
#        '2011', '1986', '1994', '1956', '1966', '1973', '1971', '1957',
#        '2013', '1981', '1972', '1959', '2004', '1962', '2019', '1978',
#        '1977', '2003', '1963', '1952', '2024', '2007', '1995', '1976',
#        '1982', '1953', '2008', '2026', '2023', '1941', '2028', '1993',
#        '2016', '2027', '2017', '2022', '1932', '2012', '1960', '2006',
#        '1926', '2020', '1943', '2014', '2021', '1967', '1904', '1991',
#        '2018', '1987', '1988', '1974', '1979', '1989', '1985', '1930',
#        '2005', '1958', '1996', '1940', '1948', '1961', '1938', '1997',
#        '2002', '2001', '1999', '1983', '1998', '1902', '2000', '1915',
#        '1910', '1939', '1929', '1954', '1897', '1900', '1955', '1949',
#        '1947', '1901', '1909', '1600', '1951', '1936', '1931', '1950',
#        '1934', '1928', '1945', '1937', '1927', '1896', '1777', '2031',
#        '1935'], dtype=object)

# %%
print(f'Пропусков в столбце "year_of_construction": {df_c["year_of_construction"].isna().sum()}')
print(f'Процент пропущенных значений: {(df_c["year_of_construction"].isna().sum() / len(df_c["year_of_construction"])).round(2) * 100}')
# Out:
# Пропусков в столбце "year_of_construction": 1120
# Процент пропущенных значений: 17.0

# %%
df_c['year_of_construction'].describe()
# Out:
# count     5467
# unique     112
# top       2025
# freq       589
# Name: year_of_construction, dtype: object

# %% [markdown]
# Больше всего квартир с годом постройки\сдачи 2025
#
# Кодируем колонку с годом

# %%
df_c['year_of_construction'] = pd.to_numeric(df_c['year_of_construction'], errors ='raise')
df_c['year_of_construction']
# Out:
# <ipython-input-362-96ad8a80ec9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['year_of_construction'] = pd.to_numeric(df_c['year_of_construction'], errors ='raise')
# 0       1917.0
# 1       1975.0
# 2          NaN
# 3       1968.0
# 4       2009.0
#          ...
# 8388    2018.0
# 8389    2025.0
# 8390    1968.0
# 8391    2023.0
# 8392    2025.0
# Name: year_of_construction, Length: 6587, dtype: float64

# %% [markdown]
# ---
#
#
# Смотрим типы данных в колонках

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6587 entries, 0 to 8392
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              6587 non-null   object
#  1   floor                 6587 non-null   int64
#  2   floors_count          6587 non-null   int64
#  3   rooms_count           6587 non-null   int64
#  4   total_meters          6587 non-null   float64
#  5   price                 6587 non-null   int64
#  6   year_of_construction  5467 non-null   float64
#  7   object_type           6587 non-null   int64
#  8   have_loggia           6587 non-null   object
#  9   parking_type          6587 non-null   object
#  10  living_meters         5128 non-null   object
#  11  kitchen_meters        5500 non-null   object
#  12  ceiling_height        6587 non-null   float64
#  13  street                5193 non-null   object
#  14  underground           4617 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 823.4+ KB

# %% [markdown]
# ---
#
#
#
# *   Кодируем оставшиеся колонки со значениями типа object, кроме площади кухни и жилой площади

# %%
# выводим уникальные значения
print(f'''have_loggia: {df_c['have_loggia'].unique()}
{'-'*150}
street: {df_c['street'].unique()}
{'-'*150}
underground: {df_c['underground'].unique()}
{'-'*150}
parking_type: {df_c['parking_type'].unique()}
{'-'*150}
location: {df_c['location'].unique()}''')
# Out:
# have_loggia: ['0' '1 лоджия' '1 балкон' '3 лоджии' '2 лоджии' '1 лоджия, 1 балкон'
#  '2 балкона' '3 балкона' '4 балкона' '1 лоджия, 2 балкона'
#  '2 лоджии, 1 балкон' '2 лоджии, 2 балкона' '4 лоджии']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# street: [' Крюкова' ' Ворошилова' ' Красный Текстильщик' ... ' Разведчика Абеля'
#  'Силикатная ' 'Ярославское шоссе']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# underground: [nan 'Аннино' 'Поклонная' 'Белорусская' 'Бауманская' 'Тульская' 'Фили'
#  'Аэропорт' 'Улица 1905 года' 'Смоленская' 'Дмитровская' 'Давыдково'
#  'Маяковская' 'ЦСКА' 'Улица Академика Янгеля' 'Лермонтовский проспект'
#  'Зеленоград — Крюково' 'Говорово' 'Цветной бульвар' 'Ясенево'
#  'Преображенская площадь' 'Юго-Западная' 'Новые Черёмушки' 'Гражданская'
#  'Октябрьское поле' 'ЗИЛ' 'Орехово' 'Рассказовка' 'Арбатская'
#  'Аминьевская' 'Полянка' 'Кунцевская' 'Марьина Роща' 'Трубная'
#  'Речной вокзал' 'Павелецкая' 'Ломоносовский проспект' 'Молодёжная'
#  'Щукинская' 'Авиамоторная' 'Москва-Сити' 'Новокузнецкая' 'Алексеевская'
#  'Пушкинская' 'Сокольники' 'Нагатинская' 'Шелепиха' 'Сухаревская'
#  'Парк Победы' 'Крёкшино' 'Солнцево' 'Бунинская аллея' 'Кедровая'
#  'Филатов Луг' 'Щербинка' 'Новомосковская' 'Воронцовская' 'Парк Культуры'
#  'Фрунзенская' 'Сходненская' 'Соколиная гора' 'Ленинский проспект'
#  'Матвеевская' 'Потапово' 'Мичуринец' 'Красный Балтиец' 'Стахановская'
#  'Тёплый Стан' 'Хорошёвская' 'Краснопресненская' 'Спортивная'
#  'Савёловская' 'Кутузовская' 'Полежаевская' 'Серпуховская' 'Спартак'
#  'Сокол' 'Свиблово' 'Юго-Восточная' 'Народное Ополчение' 'Братиславская'
#  'Коптево' 'Ватутинки' 'Стрешнево' 'Марьино' 'Щёлковская' 'Пражская'
#  'Нижегородская' 'Площадь Гагарина' 'Летово' 'Силикатная' 'Апрелевка'
#  'Корниловская' 'Толстопальцево' 'Окружная' 'Румянцево' 'Новопеределкино'
#  'Пятницкое шоссе' 'Кузьминки' 'Прокшино' 'Некрасовка' 'Медведково'
#  'Новокосино' 'Каширская' 'Отрадное' 'Крымская' 'Достоевская' 'Никольское'
#  'Реутов' 'Одинцово' 'Люберцы' 'Лухмановская' 'Академическая' 'Приморская'
#  'Курская' 'Чкаловская' 'Верхние Лихоборы' 'Ховрино' 'Проспект Ветеранов'
#  'Шаболовская' 'Динамо' 'Технопарк' 'Рабочий посёлок' 'Площадь Маркса'
#  'Комендантский проспект' 'Китай-город' 'Новослободская' 'Дубровка' 'ВДНХ'
#  'Серебряный Бор' 'Славянский бульвар' 'Деловой центр' 'Дубравная'
#  'Москва-Товарная' 'Ломоносовская' 'Алма-Атинская' 'Железнодорожная'
#  'Фонвизинская' 'Крестовский остров' 'Хлебниково' 'Долгопрудная' 'Водники'
#  'Селигерская' 'Коломенская' 'Боровицкая' 'Верхние котлы' 'Ольховая'
#  'Филёвский парк' 'Кантемировская' 'Площадь Революции' 'Раменки'
#  'Киевская' 'Тушинская' 'Кропоткинская' 'Саларьево' 'Водный стадион'
#  'Лобня' 'Планерная' 'Сходня' 'Подрезково' 'Молжаниново' 'Шереметьевская'
#  'Химки' 'Новоподрезково' 'Левобережная' 'Перово' 'Угрешская'
#  'Электрозаводская' 'Кузнецкий мост' 'Южная' 'Кавказский бульвар'
#  'Первомайская' 'Профсоюзная' 'Воробьёвы горы' 'Минская' 'Люблино'
#  'Мнёвники' 'Мичуринский проспект' 'Ботанический сад' 'Москворечье'
#  'Домодедовская' 'Зюзино' 'Тропарёво' 'Красносельская' 'Озёрная'
#  'Бульвар Генерала Карбышева' 'Беломорская' 'Нагорная' 'Пыхтино'
#  'Тургеневская' 'Варшавская' 'Владыкино' 'Ростокино' 'Комсомольская'
#  'Алтуфьево' 'Физтех' 'Кокошкино' 'Новогиреево' 'Тверская' 'Беговая'
#  'Менделеевская' 'Семёновская' 'Автозаводская' 'Крестьянская застава'
#  'Волоколамская' 'Трикотажная' 'Новаторская' 'Площадь Ильича' 'Калитники'
#  'Салтыковская' 'Кучино' 'Ольгино' 'Остафьево' 'Подольск' 'Раменское'
#  'Есенинская' 'Фабричная' 'Ипподром' 'Панки' 'Павшино' 'Бутово'
#  'Красногорская' 'Новодачная' 'Площадь 1905 года' 'Пионерская'
#  'Козья слобода' 'Бабушкинская' 'Горки' 'Серп и Молот' 'Терехово '
#  'Кремлёвская' 'Рыбацкое' 'Авиастроительная' 'Северный Вокзал' 'Ладожская'
#  'Яшьлек' 'Проспект Победы' 'Новочеркасская' 'Проспект Большевиков'
#  'Парнас' 'Выборгская' 'Черная речка' 'Студенческая' 'Площадь Ленина'
#  'Улица Дыбенко' 'Московские ворота' 'Гагаринская' 'Кировский завод'
#  'Горьковская' 'Площадь Тукая' 'Горный институт' 'Сколково' 'Липовая Роща'
#  'Лубянка' 'Безымянка' 'Девяткино' 'Технологический институт' 'Ильинская'
#  'Елизаровская' 'Балтийская' 'Звездная' 'Алабинская' 'Купчино' 'Аметьево'
#  'Строгино' 'Победа' 'Курьяново' 'Зорге' 'Черкизовская' 'Третьяковская'
#  'Пролетарская' 'Улица Милашенкова' 'Красные ворота' 'Перерва'
#  'Кожуховская' 'Хорошёво' 'Октябрьская' 'Театральная' 'Панфиловская'
#  'Бутырская' 'Университет' 'Машиностроителей' 'Удельная' 'Опалиха'
#  'Царицыно' 'Василеостровская' 'Бульвар Рокоссовского' 'Площадь Мужества'
#  'Бачуринская' 'Гражданский проспект' 'Заельцовская' 'Ботаническая'
#  'Котельники' 'Выхино' 'Грачёвская' 'Гольяново' 'Улица Сергея Эйзенштейна'
#  'Партизанская' 'Битца' 'Бирюлёво' 'Коньково' 'Крылатское' 'Нахабино'
#  'Ухтомская' 'Жулебино' 'Проспект Просвещения' 'Митино' 'Обводный канал'
#  'Площадь Восстания' 'Лесная' 'Чернышевская' 'Гостиный двор'
#  'Севастопольская' 'Автово' 'Геологическая' 'Юнгородок' 'Отдых' 'Внуково'
#  'Волковская' 'Шушары' 'Фирсановская' 'Марк' 'Пенягино' 'Аникеевка'
#  'Мякинино' 'Белокаменная']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# parking_type: ['Наземная' '0' 'Многоуровневая' 'Подземная' 'Открытая']
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# location: ['Серпухов' 'Дубна' 'Москва' 'Яхрома' 'Яхромаа' 'Воскресенск' 'Талдом'
#  'Руза' 'Реутов' 'Краснозаводск' 'Одинцово' 'Люберцы' 'Ивантеевка'
#  'Котельники' 'Электросталь' 'Долгопрудный' 'Лобня' 'Химки' 'Хотьково'
#  'Балашиха' 'Домодедово' 'Раменское' 'Бекасово' 'Звенигород' 'Дмитров'
#  'Ногинск' 'Троицк' 'Щёлково' 'Королёв' 'Клин' 'Черноголовка' 'Видное'
#  'Волоколамск' 'Талодом' 'Дзержинский' 'Пересвет' 'москва' 'Фрязино'
#  'Шатура' 'Красногорск' 'Мытищи']

# %% [markdown]
# в колонке location есть такие значения как москва, Талодом и Яхромаа. Заменяем их на корректные:

# %%
# функция для замены значений
def values_loc(value):
  if value == 'москва':
    return 'Москва'
  elif value == 'Талодом':
    return 'Талдом'
  elif value == 'Яхромаа':
    return 'Яхрома'
  else:
    return value

df_c['location'] = df_c['location'].apply(values_loc)

print(f'Уникальные значения: {df_c["location"].unique()}')
# Out:
# Уникальные значения: ['Серпухов' 'Дубна' 'Москва' 'Яхрома' 'Воскресенск' 'Талдом' 'Руза'
#  'Реутов' 'Краснозаводск' 'Одинцово' 'Люберцы' 'Ивантеевка' 'Котельники'
#  'Электросталь' 'Долгопрудный' 'Лобня' 'Химки' 'Хотьково' 'Балашиха'
#  'Домодедово' 'Раменское' 'Бекасово' 'Звенигород' 'Дмитров' 'Ногинск'
#  'Троицк' 'Щёлково' 'Королёв' 'Клин' 'Черноголовка' 'Видное' 'Волоколамск'
#  'Дзержинский' 'Пересвет' 'Фрязино' 'Шатура' 'Красногорск' 'Мытищи']
# <ipython-input-365-79a5f902c359>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['location'] = df_c['location'].apply(values_loc)

# %%
# смотрим сколько чего у нас спарсилось по городам
location_counts_df = df_c['location'].value_counts().reset_index()
location_counts_df.columns = ['location', 'count']

print(location_counts_df)
# Out:
#          location  count
# 0        Балашиха   1148
# 1           Химки    778
# 2          Москва    688
# 3      Котельники    334
# 4         Щёлково    321
# 5         Королёв    287
# 6    Долгопрудный    259
# 7         Дмитров    242
# 8        Бекасово    239
# 9        Пересвет    238
# 10         Мытищи    191
# 11    Дзержинский    168
# 12   Электросталь    160
# 13           Клин    158
# 14    Красногорск    140
# 15         Яхрома    122
# 16     Домодедово    104
# 17        Люберцы     90
# 18    Волоколамск     83
# 19         Видное     78
# 20     Ивантеевка     78
# 21         Талдом     73
# 22     Звенигород     72
# 23        Фрязино     68
# 24      Раменское     61
# 25       Серпухов     57
# 26          Дубна     57
# 27          Лобня     54
# 28           Руза     54
# 29         Троицк     52
# 30       Хотьково     31
# 31   Черноголовка     23
# 32  Краснозаводск     23
# 33         Реутов     15
# 34    Воскресенск     14
# 35         Шатура     13
# 36        Ногинск     12
# 37       Одинцово      2

# %%
# кодируем
from sklearn import preprocessing

columns = ['have_loggia', 'street', 'underground', 'parking_type', 'location']

for col in columns:
  le = preprocessing.LabelEncoder()
  df_c[col] = le.fit_transform(df_c[col])
  integer_mapping = {l: i for i, l in enumerate(le.classes_)}

print(f'Новое значения по колонке {col}: {integer_mapping}')
# Out:
# Новое значения по колонке location: {'Балашиха': 0, 'Бекасово': 1, 'Видное': 2, 'Волоколамск': 3, 'Воскресенск': 4, 'Дзержинский': 5, 'Дмитров': 6, 'Долгопрудный': 7, 'Домодедово': 8, 'Дубна': 9, 'Звенигород': 10, 'Ивантеевка': 11, 'Клин': 12, 'Королёв': 13, 'Котельники': 14, 'Красногорск': 15, 'Краснозаводск': 16, 'Лобня': 17, 'Люберцы': 18, 'Москва': 19, 'Мытищи': 20, 'Ногинск': 21, 'Одинцово': 22, 'Пересвет': 23, 'Раменское': 24, 'Реутов': 25, 'Руза': 26, 'Серпухов': 27, 'Талдом': 28, 'Троицк': 29, 'Фрязино': 30, 'Химки': 31, 'Хотьково': 32, 'Черноголовка': 33, 'Шатура': 34, 'Щёлково': 35, 'Электросталь': 36, 'Яхрома': 37}
# <ipython-input-367-62366118051f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c[col] = le.fit_transform(df_c[col])
# <ipython-input-367-62366118051f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c[col] = le.fit_transform(df_c[col])
# <ipython-input-367-62366118051f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c[col] = le.fit_transform(df_c[col])
# <ipython-input-367-62366118051f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c[col] = le.fit_transform(df_c[col])
# <ipython-input-367-62366118051f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c[col] = le.fit_transform(df_c[col])

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6587 entries, 0 to 8392
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              6587 non-null   int64
#  1   floor                 6587 non-null   int64
#  2   floors_count          6587 non-null   int64
#  3   rooms_count           6587 non-null   int64
#  4   total_meters          6587 non-null   float64
#  5   price                 6587 non-null   int64
#  6   year_of_construction  5467 non-null   float64
#  7   object_type           6587 non-null   int64
#  8   have_loggia           6587 non-null   int64
#  9   parking_type          6587 non-null   int64
#  10  living_meters         5128 non-null   object
#  11  kitchen_meters        5500 non-null   object
#  12  ceiling_height        6587 non-null   float64
#  13  street                6587 non-null   int64
#  14  underground           6587 non-null   int64
# dtypes: float64(3), int64(10), object(2)
# memory usage: 823.4+ KB

# %% [markdown]
# Кодируем жилую площадь и площадь кухни

# %%
# уник. знач. living_meters
df_c['living_meters'].unique()
# Out:
# array(['18\xa0м²', nan, '20\xa0м²', '25\xa0м²', '29,7\xa0м²',
#        '24,9\xa0м²', '13,4\xa0м²', '14,1\xa0м²', '28\xa0м²', '15\xa0м²',
#        '19\xa0м²', '16\xa0м²', '40\xa0м²', '45\xa0м²', '50\xa0м²',
#        '44\xa0м²', '39\xa0м²', '41\xa0м²', '32,5\xa0м²', '27,4\xa0м²',
#        '17\xa0м²', '33\xa0м²', '27\xa0м²', '34\xa0м²', '30\xa0м²',
#        '30,7\xa0м²', '29\xa0м²', '38\xa0м²', '28,9\xa0м²', '26\xa0м²',
#        '18,1\xa0м²', '13\xa0м²', '18,2\xa0м²', '9\xa0м²', '14\xa0м²',
#        '11,4\xa0м²', '19,3\xa0м²', '20,7\xa0м²', '32\xa0м²', '28,6\xa0м²',
#        '41,5\xa0м²', '31,2\xa0м²', '56,5\xa0м²', '48,8\xa0м²', '37\xa0м²',
#        '50,5\xa0м²', '37,7\xa0м²', '39,4\xa0м²', '52\xa0м²', '52,1\xa0м²',
#        '39,1\xa0м²', '35,2\xa0м²', '69\xa0м²', '35,7\xa0м²', '36,1\xa0м²',
#        '23,4\xa0м²', '26,8\xa0м²', '18,8\xa0м²', '45,8\xa0м²',
#        '32,8\xa0м²', '6,3\xa0м²', '10,5\xa0м²', '28,2\xa0м²',
#        '13,5\xa0м²', '15,2\xa0м²', '10,3\xa0м²', '12,8\xa0м²',
#        '70,9\xa0м²', '46,6\xa0м²', '52,6\xa0м²', '36,7\xa0м²', '60\xa0м²',
#        '52,2\xa0м²', '112\xa0м²', '51,2\xa0м²', '139,1\xa0м²',
#        '101,4\xa0м²', '57,3\xa0м²', '55\xa0м²', '93\xa0м²', '34,3\xa0м²',
#        '37,1\xa0м²', '27,6\xa0м²', '54,1\xa0м²', '53\xa0м²', '138\xa0м²',
#        '40,5\xa0м²', '42,6\xa0м²', '24,3\xa0м²', '40,4\xa0м²',
#        '40,9\xa0м²', '41,4\xa0м²', '38,7\xa0м²', '28,1\xa0м²',
#        '24,8\xa0м²', '35\xa0м²', '54\xa0м²', '34,8\xa0м²', '36\xa0м²',
#        '25,9\xa0м²', '29,6\xa0м²', '31,4\xa0м²', '25,5\xa0м²',
#        '23,9\xa0м²', '33,7\xa0м²', '33,1\xa0м²', '52,9\xa0м²',
#        '20,4\xa0м²', '31,7\xa0м²', '22,1\xa0м²', '21,5\xa0м²',
#        '18,4\xa0м²', '7,6\xa0м²', '14,3\xa0м²', '17,3\xa0м²', '23\xa0м²',
#        '16,2\xa0м²', '41,7\xa0м²', '24\xa0м²', '21,7\xa0м²', '12,3\xa0м²',
#        '8,6\xa0м²', '8\xa0м²', '18,9\xa0м²', '11,7\xa0м²', '27,7\xa0м²',
#        '17,1\xa0м²', '16,1\xa0м²', '11,2\xa0м²', '24,2\xa0м²',
#        '10,8\xa0м²', '15,3\xa0м²', '12\xa0м²', '11,3\xa0м²', '12,9\xa0м²',
#        '25,4\xa0м²', '10,4\xa0м²', '9,5\xa0м²', '11\xa0м²', '10,2\xa0м²',
#        '14,4\xa0м²', '20,1\xa0м²', '7,1\xa0м²', '17,9\xa0м²',
#        '13,1\xa0м²', '10,1\xa0м²', '21,3\xa0м²', '13,9\xa0м²',
#        '16,8\xa0м²', '13,2\xa0м²', '18,7\xa0м²', '15,1\xa0м²',
#        '16,5\xa0м²', '17,5\xa0м²', '11,1\xa0м²', '17,6\xa0м²',
#        '16,6\xa0м²', '7\xa0м²', '14,6\xa0м²', '37,8\xa0м²', '22\xa0м²',
#        '31,5\xa0м²', '54,6\xa0м²', '36,3\xa0м²', '56\xa0м²', '18,3\xa0м²',
#        '17,8\xa0м²', '17,7\xa0м²', '19,4\xa0м²', '15,5\xa0м²',
#        '19,8\xa0м²', '10\xa0м²', '27,9\xa0м²', '21\xa0м²', '16,4\xa0м²',
#        '21,2\xa0м²', '20,9\xa0м²', '15,9\xa0м²', '9,9\xa0м²',
#        '30,3\xa0м²', '25,3\xa0м²', '19,5\xa0м²', '29,1\xa0м²',
#        '16,7\xa0м²', '26,7\xa0м²', '21,8\xa0м²', '9,6\xa0м²',
#        '14,2\xa0м²', '21,6\xa0м²', '9,1\xa0м²', '46,9\xa0м²',
#        '10,9\xa0м²', '10,6\xa0м²', '24,4\xa0м²', '14,7\xa0м²',
#        '18,5\xa0м²', '12,1\xa0м²', '17,2\xa0м²', '16,9\xa0м²',
#        '28,4\xa0м²', '25,7\xa0м²', '22,2\xa0м²', '30,5\xa0м²',
#        '15,7\xa0м²', '27,2\xa0м²', '32,7\xa0м²', '84,7\xa0м²',
#        '40,6\xa0м²', '32,6\xa0м²', '29,5\xa0м²', '12,5\xa0м²',
#        '19,1\xa0м²', '31\xa0м²', '29,9\xa0м²', '26,4\xa0м²', '36,6\xa0м²',
#        '29,2\xa0м²', '42,9\xa0м²', '90\xa0м²', '39,7\xa0м²', '22,9\xa0м²',
#        '19,6\xa0м²', '24,1\xa0м²', '34,6\xa0м²', '28,8\xa0м²', '70\xa0м²',
#        '38,8\xa0м²', '170\xa0м²', '31,6\xa0м²', '28,3\xa0м²',
#        '33,8\xa0м²', '51,7\xa0м²', '5\xa0м²', '40,1\xa0м²', '36,9\xa0м²',
#        '33,6\xa0м²', '36,5\xa0м²', '42\xa0м²', '15,6\xa0м²', '13,3\xa0м²',
#        '20,5\xa0м²', '35,4\xa0м²', '51,4\xa0м²', '48\xa0м²', '36,8\xa0м²',
#        '82\xa0м²', '110\xa0м²', '37,3\xa0м²', '46\xa0м²', '23,8\xa0м²',
#        '23,7\xa0м²', '28,5\xa0м²', '22,6\xa0м²', '32,1\xa0м²',
#        '11,8\xa0м²', '14,5\xa0м²', '9,7\xa0м²', '48,9\xa0м²',
#        '12,2\xa0м²', '19,9\xa0м²', '34,5\xa0м²', '25,8\xa0м²',
#        '13,7\xa0м²', '15,8\xa0м²', '12,4\xa0м²', '39,3\xa0м²',
#        '20,8\xa0м²', '19,2\xa0м²', '14,8\xa0м²', '17,4\xa0м²',
#        '37,4\xa0м²', '25,2\xa0м²', '33,9\xa0м²', '45,1\xa0м²',
#        '50,4\xa0м²', '98,9\xa0м²', '67\xa0м²', '10,7\xa0м²', '80\xa0м²',
#        '84\xa0м²', '70,1\xa0м²', '56,6\xa0м²', '48,1\xa0м²', '98,6\xa0м²',
#        '124,2\xa0м²', '52,4\xa0м²', '64,5\xa0м²', '102,2\xa0м²',
#        '53,1\xa0м²', '112,8\xa0м²', '67,1\xa0м²', '80,9\xa0м²',
#        '61\xa0м²', '43,1\xa0м²', '140,9\xa0м²', '104,6\xa0м²',
#        '140\xa0м²', '58,4\xa0м²', '300\xa0м²', '66,6\xa0м²', '97,5\xa0м²',
#        '110,9\xa0м²', '85,3\xa0м²', '71,8\xa0м²', '127\xa0м²',
#        '11,6\xa0м²', '8,8\xa0м²', '12,7\xa0м²', '18,6\xa0м²',
#        '13,8\xa0м²', '9,4\xa0м²', '44,9\xa0м²', '27,8\xa0м²',
#        '20,3\xa0м²', '52,7\xa0м²', '53,6\xa0м²', '64,4\xa0м²',
#        '34,4\xa0м²', '33,5\xa0м²', '62\xa0м²', '31,9\xa0м²', '27,5\xa0м²',
#        '53,9\xa0м²', '47,6\xa0м²', '30,4\xa0м²', '12,6\xa0м²',
#        '34,1\xa0м²', '11,5\xa0м²', '49,9\xa0м²', '34,2\xa0м²',
#        '31,3\xa0м²', '29,3\xa0м²', '39,2\xa0м²', '26,3\xa0м²',
#        '20,2\xa0м²', '26,5\xa0м²', '43\xa0м²', '29,4\xa0м²', '23,3\xa0м²',
#        '32,4\xa0м²', '35,3\xa0м²', '16,3\xa0м²', '53,4\xa0м²', '71\xa0м²',
#        '22,5\xa0м²', '50,3\xa0м²', '33,3\xa0м²', '30,2\xa0м²',
#        '26,6\xa0м²', '37,2\xa0м²', '36,2\xa0м²', '36,4\xa0м²',
#        '30,9\xa0м²', '49\xa0м²', '42,5\xa0м²', '23,2\xa0м²', '28,7\xa0м²',
#        '37,6\xa0м²', '27,1\xa0м²', '35,6\xa0м²', '58,2\xa0м²',
#        '33,2\xa0м²', '25,6\xa0м²', '31,8\xa0м²', '24,6\xa0м²',
#        '48,3\xa0м²', '58\xa0м²', '96,9\xa0м²', '25,1\xa0м²', '27,3\xa0м²',
#        '23,1\xa0м²', '21,9\xa0м²', '13,6\xa0м²', '24,5\xa0м²',
#        '31,1\xa0м²', '51,5\xa0м²', '22,4\xa0м²', '15,4\xa0м²',
#        '39,6\xa0м²', '47\xa0м²', '49,5\xa0м²', '44,5\xa0м²', '29,8\xa0м²',
#        '41,2\xa0м²', '33,4\xa0м²', '32,3\xa0м²', '26,2\xa0м²',
#        '21,1\xa0м²', '21,4\xa0м²', '30,6\xa0м²', '41,3\xa0м²',
#        '26,9\xa0м²', '30,8\xa0м²', '26,1\xa0м²', '39,5\xa0м²',
#        '35,8\xa0м²', '40,7\xa0м²', '38,4\xa0м²', '46,1\xa0м²',
#        '34,7\xa0м²', '43,6\xa0м²', '23,6\xa0м²', '38,9\xa0м²',
#        '38,1\xa0м²', '47,8\xa0м²', '45,3\xa0м²', '67,2\xa0м²',
#        '48,5\xa0м²', '62,2\xa0м²', '43,5\xa0м²', '57,2\xa0м²', '65\xa0м²',
#        '49,1\xa0м²', '58,3\xa0м²', '42,1\xa0м²', '55,9\xa0м²',
#        '54,2\xa0м²', '38,6\xa0м²', '51\xa0м²', '52,3\xa0м²', '48,2\xa0м²',
#        '42,4\xa0м²', '48,7\xa0м²', '56,1\xa0м²', '45,5\xa0м²', '63\xa0м²',
#        '64\xa0м²', '39,8\xa0м²', '62,5\xa0м²', '43,2\xa0м²', '35,5\xa0м²',
#        '54,3\xa0м²', '49,4\xa0м²', '53,5\xa0м²', '41,8\xa0м²',
#        '47,1\xa0м²', '55,1\xa0м²', '40,2\xa0м²', '59\xa0м²', '56,2\xa0м²',
#        '43,4\xa0м²', '68\xa0м²', '43,9\xa0м²', '52,8\xa0м²', '45,4\xa0м²',
#        '45,6\xa0м²', '49,2\xa0м²', '44,7\xa0м²', '37,5\xa0м²',
#        '41,1\xa0м²', '46,3\xa0м²', '45,7\xa0м²', '67,4\xa0м²',
#        '49,8\xa0м²', '43,3\xa0м²', '47,7\xa0м²', '48,6\xa0м²',
#        '50,6\xa0м²', '38,5\xa0м²', '57\xa0м²', '46,8\xa0м²', '11,9\xa0м²',
#        '104\xa0м²', '53,8\xa0м²', '72,3\xa0м²', '94\xa0м²', '80,3\xa0м²',
#        '91\xa0м²', '109\xa0м²', '175,8\xa0м²', '59,2\xa0м²', '71,3\xa0м²',
#        '100\xa0м²', '59,9\xa0м²', '61,7\xa0м²', '101\xa0м²', '47,2\xa0м²',
#        '51,9\xa0м²', '61,8\xa0м²', '75,4\xa0м²', '68,7\xa0м²',
#        '50,7\xa0м²', '60,5\xa0м²', '74,2\xa0м²', '102\xa0м²',
#        '63,7\xa0м²', '55,7\xa0м²', '75,6\xa0м²', '118\xa0м²', '75\xa0м²',
#        '63,5\xa0м²', '47,3\xa0м²', '44,4\xa0м²', '30,1\xa0м²',
#        '40,3\xa0м²', '35,1\xa0м²', '32,2\xa0м²', '38,3\xa0м²',
#        '49,7\xa0м²', '9,2\xa0м²', '14,9\xa0м²', '19,7\xa0м²',
#        '90,7\xa0м²', '20,6\xa0м²', '23,5\xa0м²', '22,8\xa0м²',
#        '24,7\xa0м²', '39,9\xa0м²', '56,7\xa0м²', '35,9\xa0м²',
#        '47,4\xa0м²', '8,4\xa0м²', '7,7\xa0м²', '22,3\xa0м²', '8,5\xa0м²',
#        '8,7\xa0м²', '9,8\xa0м²', '8,2\xa0м²', '40,8\xa0м²', '58,6\xa0м²',
#        '41,9\xa0м²', '34,9\xa0м²', '43,8\xa0м²', '46,2\xa0м²',
#        '58,8\xa0м²', '37,9\xa0м²', '72,5\xa0м²', '73\xa0м²', '56,4\xa0м²',
#        '3\xa0м²', '190,3\xa0м²', '117\xa0м²', '88,8\xa0м²', '65,7\xa0м²',
#        '85,7\xa0м²', '77,6\xa0м²', '97,6\xa0м²', '196,9\xa0м²',
#        '113\xa0м²', '63,3\xa0м²', '79,2\xa0м²', '80,1\xa0м²', '191\xa0м²',
#        '67,8\xa0м²', '184\xa0м²', '92,8\xa0м²', '84,8\xa0м²',
#        '45,9\xa0м²', '44,8\xa0м²', '44,6\xa0м²', '94,9\xa0м²',
#        '38,2\xa0м²', '55,8\xa0м²', '43,7\xa0м²', '76,9\xa0м²',
#        '44,3\xa0м²', '57,1\xa0м²', '53,2\xa0м²', '45,2\xa0м²',
#        '51,8\xa0м²', '41,6\xa0м²', '42,8\xa0м²', '44,2\xa0м²',
#        '50,1\xa0м²', '47,5\xa0м²', '86,3\xa0м²', '88,5\xa0м²', '95\xa0м²',
#        '75,8\xa0м²', '77\xa0м²', '56,9\xa0м²', '66\xa0м²', '49,6\xa0м²',
#        '55,2\xa0м²', '32,9\xa0м²', '59,7\xa0м²', '55,4\xa0м²',
#        '53,7\xa0м²', '42,3\xa0м²', '22,7\xa0м²'], dtype=object)

# %%
# уник. знач. kitchen_meters
df_c['kitchen_meters'].unique()
# Out:
# array(['1\xa0м²', '6\xa0м²', nan, '5\xa0м²', '5,6\xa0м²', '3\xa0м²',
#        '6,2\xa0м²', '7\xa0м²', '7,3\xa0м²', '6,1\xa0м²', '10\xa0м²',
#        '9\xa0м²', '8\xa0м²', '5,7\xa0м²', '11\xa0м²', '7,5\xa0м²',
#        '13,5\xa0м²', '6,5\xa0м²', '5,8\xa0м²', '20\xa0м²', '11,2\xa0м²',
#        '7,8\xa0м²', '4\xa0м²', '7,9\xa0м²', '4,1\xa0м²', '12\xa0м²',
#        '7,7\xa0м²', '8,1\xa0м²', '9,3\xa0м²', '10,2\xa0м²', '10,6\xa0м²',
#        '8,5\xa0м²', '9,1\xa0м²', '4,5\xa0м²', '6,7\xa0м²', '45\xa0м²',
#        '34,3\xa0м²', '25,5\xa0м²', '46,2\xa0м²', '4,9\xa0м²', '8,4\xa0м²',
#        '24,9\xa0м²', '15\xa0м²', '15,8\xa0м²', '11,5\xa0м²', '5,5\xa0м²',
#        '10,7\xa0м²', '19,4\xa0м²', '43,8\xa0м²', '44,5\xa0м²',
#        '22,4\xa0м²', '25\xa0м²', '28,4\xa0м²', '19\xa0м²', '16\xa0м²',
#        '21\xa0м²', '5,1\xa0м²', '18,3\xa0м²', '3,8\xa0м²', '19,2\xa0м²',
#        '16,2\xa0м²', '21,7\xa0м²', '12,5\xa0м²', '15,4\xa0м²', '28\xa0м²',
#        '17\xa0м²', '10,4\xa0м²', '13,6\xa0м²', '21,8\xa0м²', '14\xa0м²',
#        '12,9\xa0м²', '13\xa0м²', '29,2\xa0м²', '23\xa0м²', '15,7\xa0м²',
#        '2,9\xa0м²', '8,2\xa0м²', '2,4\xa0м²', '20,7\xa0м²', '4,3\xa0м²',
#        '18\xa0м²', '21,3\xa0м²', '11,6\xa0м²', '16,8\xa0м²', '3,9\xa0м²',
#        '9,9\xa0м²', '19,3\xa0м²', '11,3\xa0м²', '14,8\xa0м²',
#        '17,1\xa0м²', '21,4\xa0м²', '8,9\xa0м²', '18,2\xa0м²',
#        '13,4\xa0м²', '16,4\xa0м²', '16,5\xa0м²', '8,7\xa0м²', '9,8\xa0м²',
#        '10,8\xa0м²', '18,5\xa0м²', '16,1\xa0м²', '13,2\xa0м²',
#        '8,6\xa0м²', '4,8\xa0м²', '9,5\xa0м²', '6,3\xa0м²', '3,5\xa0м²',
#        '43\xa0м²', '65\xa0м²', '9,2\xa0м²', '12,7\xa0м²', '10,1\xa0м²',
#        '12,8\xa0м²', '10,5\xa0м²', '25,6\xa0м²', '6,4\xa0м²', '7,2\xa0м²',
#        '9,7\xa0м²', '15,2\xa0м²', '7,6\xa0м²', '9,6\xa0м²', '3,2\xa0м²',
#        '7,4\xa0м²', '5,2\xa0м²', '6,6\xa0м²', '2,5\xa0м²', '3,6\xa0м²',
#        '5,4\xa0м²', '3,3\xa0м²', '4,4\xa0м²', '16,6\xa0м²', '24\xa0м²',
#        '15,6\xa0м²', '19,9\xa0м²', '28,7\xa0м²', '15,3\xa0м²', '22\xa0м²',
#        '16,7\xa0м²', '11,9\xa0м²', '12,4\xa0м²', '23,9\xa0м²',
#        '14,3\xa0м²', '8,8\xa0м²', '4,2\xa0м²', '22,3\xa0м²', '15,5\xa0м²',
#        '21,5\xa0м²', '25,1\xa0м²', '10,3\xa0м²', '22,1\xa0м²', '30\xa0м²',
#        '11,7\xa0м²', '16,9\xa0м²', '13,3\xa0м²', '9,4\xa0м²',
#        '32,8\xa0м²', '17,4\xa0м²', '49,2\xa0м²', '11,1\xa0м²',
#        '17,8\xa0м²', '12,6\xa0м²', '26\xa0м²', '8,3\xa0м²', '12,2\xa0м²',
#        '12,3\xa0м²', '27\xa0м²', '13,8\xa0м²', '17,7\xa0м²', '14,6\xa0м²',
#        '2\xa0м²', '31\xa0м²', '18,7\xa0м²', '29,7\xa0м²', '17,2\xa0м²',
#        '17,9\xa0м²', '5,3\xa0м²', '27,8\xa0м²', '11,8\xa0м²',
#        '22,5\xa0м²', '27,4\xa0м²', '14,7\xa0м²', '6,8\xa0м²',
#        '10,9\xa0м²', '27,6\xa0м²', '38\xa0м²', '14,2\xa0м²', '36,2\xa0м²',
#        '27,1\xa0м²', '29,8\xa0м²', '14,1\xa0м²', '33,4\xa0м²',
#        '51,4\xa0м²', '5,9\xa0м²', '26,1\xa0м²', '16,3\xa0м²', '50\xa0м²',
#        '23,6\xa0м²', '28,1\xa0м²', '74\xa0м²', '56,4\xa0м²', '18,4\xa0м²',
#        '53,7\xa0м²', '35,4\xa0м²', '3,7\xa0м²', '20,1\xa0м²',
#        '11,4\xa0м²', '20,3\xa0м²', '22,2\xa0м²', '22,9\xa0м²',
#        '18,1\xa0м²', '15,9\xa0м²', '14,4\xa0м²', '17,5\xa0м²',
#        '12,1\xa0м²', '14,5\xa0м²', '3,4\xa0м²', '6,9\xa0м²', '13,1\xa0м²',
#        '34\xa0м²', '35\xa0м²', '26,6\xa0м²', '23,4\xa0м²', '15,1\xa0м²',
#        '19,8\xa0м²', '19,6\xa0м²', '24,4\xa0м²', '4,7\xa0м²', '7,1\xa0м²',
#        '25,7\xa0м²', '21,6\xa0м²', '23,2\xa0м²', '28,6\xa0м²',
#        '23,1\xa0м²', '19,5\xa0м²', '13,7\xa0м²', '18,6\xa0м²',
#        '17,3\xa0м²', '18,8\xa0м²', '30,7\xa0м²', '28,5\xa0м²',
#        '13,9\xa0м²', '38,6\xa0м²', '24,5\xa0м²', '32\xa0м²', '24,1\xa0м²',
#        '20,9\xa0м²', '20,5\xa0м²', '23,5\xa0м²', '27,5\xa0м²',
#        '31,4\xa0м²', '43,4\xa0м²', '27,3\xa0м²', '24,2\xa0м²', '55\xa0м²',
#        '36\xa0м²', '22,6\xa0м²', '17,6\xa0м²', '21,2\xa0м²', '34,7\xa0м²',
#        '34,1\xa0м²', '19,1\xa0м²', '2,2\xa0м²', '2,8\xa0м²', '29,9\xa0м²',
#        '31,3\xa0м²', '36,9\xa0м²', '23,8\xa0м²', '23,7\xa0м²',
#        '36,8\xa0м²', '21,9\xa0м²', '1,9\xa0м²', '40\xa0м²', '55,1\xa0м²',
#        '22,7\xa0м²', '90\xa0м²', '46\xa0м²', '52\xa0м²', '3,1\xa0м²',
#        '23,3\xa0м²', '22,8\xa0м²', '26,7\xa0м²', '18,9\xa0м²',
#        '14,9\xa0м²', '24,3\xa0м²', '4,6\xa0м²', '2,3\xa0м²', '19,7\xa0м²',
#        '20,4\xa0м²'], dtype=object)

# %%
# living_meters
df_c['living_meters'] = df_c['living_meters'].str.replace(r'\xa0м²', '', regex=True).str.replace(',', '.')
df_c['living_meters'] = df_c['living_meters'].astype(float)
df_c['living_meters']
# Out:
# <ipython-input-371-15a76277d25b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['living_meters'] = df_c['living_meters'].str.replace(r'\xa0м²', '', regex=True).str.replace(',', '.')
# <ipython-input-371-15a76277d25b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['living_meters'] = df_c['living_meters'].astype(float)
# 0       18.0
# 1       18.0
# 2        NaN
# 3        NaN
# 4       20.0
#         ...
# 8388    38.0
# 8389    22.7
# 8390     NaN
# 8391    19.0
# 8392    24.9
# Name: living_meters, Length: 6587, dtype: float64

# %%
# kitchen_meters
df_c['kitchen_meters'] = df_c['kitchen_meters'].str.replace(r'\xa0м²', '', regex=True).str.replace(',', '.')
df_c['kitchen_meters'] = df_c['kitchen_meters'].astype(float)
df_c['kitchen_meters']
# Out:
# <ipython-input-372-fdbc53ea5feb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['kitchen_meters'] = df_c['kitchen_meters'].str.replace(r'\xa0м²', '', regex=True).str.replace(',', '.')
# <ipython-input-372-fdbc53ea5feb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c['kitchen_meters'] = df_c['kitchen_meters'].astype(float)
# 0        1.0
# 1        6.0
# 2        NaN
# 3        NaN
# 4        5.0
#         ...
# 8388    10.5
# 8389    16.1
# 8390     6.0
# 8391     8.0
# 8392    21.4
# Name: kitchen_meters, Length: 6587, dtype: float64

# %% [markdown]
# ---
#
# Выводим информацию и пропуски

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6587 entries, 0 to 8392
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              6587 non-null   int64
#  1   floor                 6587 non-null   int64
#  2   floors_count          6587 non-null   int64
#  3   rooms_count           6587 non-null   int64
#  4   total_meters          6587 non-null   float64
#  5   price                 6587 non-null   int64
#  6   year_of_construction  5467 non-null   float64
#  7   object_type           6587 non-null   int64
#  8   have_loggia           6587 non-null   int64
#  9   parking_type          6587 non-null   int64
#  10  living_meters         5128 non-null   float64
#  11  kitchen_meters        5500 non-null   float64
#  12  ceiling_height        6587 non-null   float64
#  13  street                6587 non-null   int64
#  14  underground           6587 non-null   int64
# dtypes: float64(5), int64(10)
# memory usage: 823.4 KB

# %% [markdown]
# * Все колонки имеют числовой тип данных

# %%
plt.figure(figsize=(6, 3))
sns.heatmap(df_c.isnull(), cmap='BuPu_r')
# Out:
# <Axes: >

# %% [markdown]
# Пропуски остались в трёх колонках, считаем их:

# %%
null_counts = df_c.isnull().sum().reset_index()
null_counts.columns = ['Column', 'Null Count']

print(null_counts)
# Out:
#                   Column  Null Count
# 0               location           0
# 1                  floor           0
# 2           floors_count           0
# 3            rooms_count           0
# 4           total_meters           0
# 5                  price           0
# 6   year_of_construction        1120
# 7            object_type           0
# 8            have_loggia           0
# 9           parking_type           0
# 10         living_meters        1459
# 11        kitchen_meters        1087
# 12        ceiling_height           0
# 13                street           0
# 14           underground           0

# %% [markdown]
# ---
#
# Работаем с колонкой "year_of_construction"

# %%
df_c['year_of_construction'].unique()
# Out:
# array([1917., 1975.,   nan, 1968., 2009., 1969., 1980., 1990., 2025.,
#        2015., 1970., 1984., 1965., 2010., 1964., 1992., 2011., 1986.,
#        1994., 1956., 1966., 1973., 1971., 1957., 2013., 1981., 1972.,
#        1959., 2004., 1962., 2019., 1978., 1977., 2003., 1963., 1952.,
#        2024., 2007., 1995., 1976., 1982., 1953., 2008., 2026., 2023.,
#        1941., 2028., 1993., 2016., 2027., 2017., 2022., 1932., 2012.,
#        1960., 2006., 1926., 2020., 1943., 2014., 2021., 1967., 1904.,
#        1991., 2018., 1987., 1988., 1974., 1979., 1989., 1985., 1930.,
#        2005., 1958., 1996., 1940., 1948., 1961., 1938., 1997., 2002.,
#        2001., 1999., 1983., 1998., 1902., 2000., 1915., 1910., 1939.,
#        1929., 1954., 1897., 1900., 1955., 1949., 1947., 1901., 1909.,
#        1600., 1951., 1936., 1931., 1950., 1934., 1928., 1945., 1937.,
#        1927., 1896., 1777., 2031., 1935.])

# %%
df_c['year_of_construction'].describe()
# Out:
# count    5467.000000
# mean     2006.130236
# std        23.882002
# min      1600.000000
# 25%      1990.000000
# 50%      2016.000000
# 75%      2024.000000
# max      2031.000000
# Name: year_of_construction, dtype: float64

# %% [markdown]
# Минимальное и максимальное значения сомнительные, визуализируем это всё

# %%
sns.boxplot(x='price', y='year_of_construction', data=df_c)
# Out:
# <Axes: xlabel='price', ylabel='year_of_construction'>

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 15))
sns.barplot(x='year_of_construction', y='price', data=df_c, color = 'pink')
plt.xlabel('Год')
plt.ylabel('Стоимость квартиры')
plt.xticks(rotation=120)

plt.show()

# %% [markdown]
# Всё что было до 1970-го и года убираем. То что после 2024го тоже не нужно

# %%
df_c = df_c[(df_c['year_of_construction'] >= 1970) & (df_c['year_of_construction'] <= 2024)]

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 15))
sns.barplot(x='year_of_construction', y='price', data=df_c, color = 'purple')
plt.xlabel('Год')
plt.ylabel('Стоимость квартиры')
plt.xticks(rotation=120)

plt.show()

# %% [markdown]
# 1998 год считаем за выброс --> удаляем

# %%
df_c = df_c[df_c['year_of_construction'] != 1998]

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 15))
sns.barplot(x = 'year_of_construction', y ='price', data=df_c, color = 'blue')
plt.xlabel('Год')
plt.ylabel('Стоимость квартиры')
plt.xticks(rotation=120)

plt.show()

# %%
df_c['year_of_construction'].describe()
# Out:
# count    3716.000000
# mean     2007.618407
# std        16.857848
# min      1970.000000
# 25%      1999.000000
# 50%      2014.000000
# 75%      2021.000000
# max      2024.000000
# Name: year_of_construction, dtype: float64

# %% [markdown]
# Вроде как выбросы по этой колонке удалены
#
#
# ---

# %%
# смотрим инфу (пропуски)
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3716 entries, 1 to 8391
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              3716 non-null   int64
#  1   floor                 3716 non-null   int64
#  2   floors_count          3716 non-null   int64
#  3   rooms_count           3716 non-null   int64
#  4   total_meters          3716 non-null   float64
#  5   price                 3716 non-null   int64
#  6   year_of_construction  3716 non-null   float64
#  7   object_type           3716 non-null   int64
#  8   have_loggia           3716 non-null   int64
#  9   parking_type          3716 non-null   int64
#  10  living_meters         2950 non-null   float64
#  11  kitchen_meters        3271 non-null   float64
#  12  ceiling_height        3716 non-null   float64
#  13  street                3716 non-null   int64
#  14  underground           3716 non-null   int64
# dtypes: float64(5), int64(10)
# memory usage: 464.5 KB

# %%
plt.figure(figsize=(6, 3))
sns.heatmap(df_c.isnull(), cmap='ocean')
# Out:
# <Axes: >

# %% [markdown]
# ---
#
#
# Пропуски остались в колонках "living_meters" и "kitchen_meters". Чтобы их заполнить, нужно:
#
# 1) Удалить строчки, где в обоих столбцах стоит пропуск
#
# 2) В оставшихся строках записать вместо нул. значения разницу общей площади и известной площади (жилая\кухонная). Значение будет не точным, но приближенным к реальному.

# %%
# удаляем строчки где обе площади заполнены нул. значением
df_c.drop(df_c[(pd.isna(df_c['living_meters'])) & (pd.isna(df_c['kitchen_meters']))].index, inplace=True)

# %%
print(f'Пропусков в столбце "living_meters": {df_c["living_meters"].isna().sum()}')
print(f'Пропусков в столбце "kitchen_meters": {df_c["kitchen_meters"].isna().sum()}')
# Out:
# Пропусков в столбце "living_meters": 431
# Пропусков в столбце "kitchen_meters": 110

# %%
# заполняем пропуски в 'living_meters'
df_c['living_meters'].fillna(df_c['total_meters'] - df_c['kitchen_meters'], inplace=True)

# заполняем пропуски в 'kitchen_meters'
df_c['kitchen_meters'].fillna(df_c['total_meters'] - df_c['living_meters'], inplace=True)
# Out:
# <ipython-input-389-d46e8a89959d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_c['living_meters'].fillna(df_c['total_meters'] - df_c['kitchen_meters'], inplace=True)
# <ipython-input-389-d46e8a89959d>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_c['kitchen_meters'].fillna(df_c['total_meters'] - df_c['living_meters'], inplace=True)

# %%
# пропуски
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3381 entries, 1 to 8391
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   location              3381 non-null   int64
#  1   floor                 3381 non-null   int64
#  2   floors_count          3381 non-null   int64
#  3   rooms_count           3381 non-null   int64
#  4   total_meters          3381 non-null   float64
#  5   price                 3381 non-null   int64
#  6   year_of_construction  3381 non-null   float64
#  7   object_type           3381 non-null   int64
#  8   have_loggia           3381 non-null   int64
#  9   parking_type          3381 non-null   int64
#  10  living_meters         3381 non-null   float64
#  11  kitchen_meters        3381 non-null   float64
#  12  ceiling_height        3381 non-null   float64
#  13  street                3381 non-null   int64
#  14  underground           3381 non-null   int64
# dtypes: float64(5), int64(10)
# memory usage: 422.6 KB

# %%
plt.figure(figsize=(6, 3))
sns.heatmap(df_c.isnull(), cmap='winter')
# Out:
# <Axes: >

# %% [markdown]
# Пропусков больше нет!!! 🥳✅

# %% [markdown]
# ---

# %% [markdown]
# ## Работа с оставшимися выбросами

# %%
# лист с колонками, в которых могут быть выбросы (атрибуты, хранящие численные по смыслу данные)
st_columns = df_c[['floor', 'total_meters', 'price', 'living_meters', 'kitchen_meters']]

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 15))
# создаём боксплот для каждой колонки
for i, column in enumerate(st_columns):
  row = i//3
  col = i % 3
  sns.boxplot(x=st_columns[column], ax = axes[row, col], color = 'purple')
  axes[row, col].set_title(f'{column} boxplot')

plt.subplots_adjust(hspace = 0.9)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ---
#
# ### total_meters

# %%
df_c['total_meters'].describe()
# Out:
# count    3381.000000
# mean       54.681659
# std        30.191025
# min        14.300000
# 25%        37.400000
# 50%        48.600000
# 75%        63.400000
# max       475.000000
# Name: total_meters, dtype: float64

# %%
# выводим 20 макс. значений
df_c.loc[df_c['total_meters'].nlargest(20).index]
# Out:
#       location  floor  floors_count  rooms_count  total_meters      price  \
# 396         37      3             5            2        475.00    4799000
# 5867        19      1             7            5        398.10  170000000
# 5838        19     21            21            5        363.30  629417250
# 5849        19      6             6            5        310.15  325657500
# 5854        19     57            75            5        304.00  260000000
# 5839        19     11            12            5        303.00  531661349
# 5861        19     60            75            5        294.70  294700000
# 5843        19      2            12            5        290.00  280000000
# 2998        19      4             4            4        288.00  574431000
# 2984        19     82            85            4        285.00  251000000
# 2644         0      1             2            3        276.90   29999999
# 1178        19     16            16            5        269.00   95000000
# 1173        19      2             8            5        250.00  225000000
# 2994        19     25            26            4        250.00   64849000
# 1158        19     26            31            5        246.70  288063785
# 1161        19      3             9            5        234.80  125000000
# 1134        19     18            21            4        234.30  344593211
# 5845        19     12            14            5        227.40  834760000
# 5846        19     27            31            5        212.00  115000000
# 3050        19      2             4            4        210.00  124970000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 396                 1977.0            1            1             2
# 5867                2005.0            1            0             0
# 5838                2023.0            0            0             4
# 5849                2023.0            1            0             4
# 5854                2010.0            1            0             0
# 5839                2014.0            1            1             4
# 5861                2015.0            1            0             4
# 5843                2006.0            1            2             0
# 2998                2024.0            1            5             0
# 2984                2016.0            1            0             4
# 2644                1991.0            1            0             0
# 1178                1999.0            1            8             4
# 1173                2010.0            1            0             4
# 2994                2005.0            1            2             4
# 1158                2008.0            1            9             4
# 1161                1999.0            1            4             4
# 1134                2023.0            0            0             0
# 5845                2024.0            0            1             4
# 5846                2008.0            1            1             0
# 3050                1990.0            1            0             3
#
#       living_meters  kitchen_meters  ceiling_height  street  underground
# 396            33.0             7.0            2.81    1418          325
# 5867          378.1            20.0            3.00     951          112
# 5838          190.3            31.4            2.81     749          284
# 5849          196.9            22.7            4.55     904          192
# 5854          140.0            90.0            3.00    1304           65
# 5839          117.0            24.0            3.20    1178          298
# 5861          191.0            46.0            5.00    1304           65
# 5843          250.0            40.0            2.81     650          145
# 2998          268.0            20.0            3.72     603           92
# 2984          175.8            15.4            4.50     731           65
# 2644           62.0            30.7            2.95     681          122
# 1178          219.0            50.0            3.00     916          295
# 1173          230.0            20.0            3.00     756          298
# 2994          100.0            50.0            3.00     330          320
# 1158          140.9            28.0            3.10    1015           63
# 1161          140.0            23.0            2.81     945          172
# 1134          207.2            27.1            3.00     327          284
# 5845           85.7            55.1            3.35    1418          216
# 5846          192.0            20.0            3.10    1015           63
# 3050          180.0            30.0            3.00    1069          228

# %%
sns.boxplot(x=df_c['total_meters'], color = 'red')
# Out:
# <Axes: xlabel='total_meters'>

# %% [markdown]
# Удаляем строки,где общая площадь квартиры больше 200

# %%
df_c = df_c[df_c['total_meters'] < 200]

# %%
df_c['total_meters'].describe()
# Out:
# count    3359.00000
# mean       53.21713
# std        23.66211
# min        14.30000
# 25%        37.30000
# 50%        48.30000
# 75%        63.00000
# max       199.80000
# Name: total_meters, dtype: float64

# %% [markdown]
# ---
#
# ### floor

# %%
df_c['floor'].describe()
# Out:
# count    3359.000000
# mean        7.787734
# std         5.884526
# min         1.000000
# 25%         3.000000
# 50%         6.000000
# 75%        11.000000
# max        75.000000
# Name: floor, dtype: float64

# %%
sns.boxplot(x=df_c['floor'], color = 'yellow')
# Out:
# <Axes: xlabel='floor'>

# %% [markdown]
# Выводим строчку с выбросом

# %%
df_c.loc[df_c['floor'].nlargest(1).index]
# Out:
#      location  floor  floors_count  rooms_count  total_meters     price  \
# 617        14     75            95            1          57.0  47000000
#
#      year_of_construction  object_type  have_loggia  parking_type  \
# 617                2017.0            1            0             4
#
#      living_meters  kitchen_meters  ceiling_height  street  underground
# 617           37.0            10.0             3.0    1304           65

# %%
# удаляем её
df_c.drop(617, inplace=True)

# %%
sns.boxplot(x=df_c['floor'], color = 'yellow')
# Out:
# <Axes: xlabel='floor'>

# %% [markdown]
# ---
#
#
# ### living_meters

# %%
df_c['living_meters'].describe()
# Out:
# count    3358.000000
# mean       30.965122
# std        17.663200
# min         3.000000
# 25%        18.000000
# 50%        28.300000
# 75%        39.000000
# max       179.000000
# Name: living_meters, dtype: float64

# %% [markdown]
# Макс. знач. = 179 м^2, для жилой площади в квартире значение какое-то большое

# %%
sns.boxplot(x=df_c['living_meters'], color = 'grey')
# Out:
# <Axes: xlabel='living_meters'>

# %% [markdown]
# Удаляем строчки, где жилая площадь больше чем 150

# %%
df_c = df_c[df_c['living_meters'] < 150]

df_c['living_meters'].describe()
# Out:
# count    3352.000000
# mean       30.729857
# std        16.776709
# min         3.000000
# 25%        18.000000
# 50%        28.250000
# 75%        39.000000
# max       149.800000
# Name: living_meters, dtype: float64

# %% [markdown]
# ---
#
#
# ### kitchen_meters

# %%
df_c['kitchen_meters'].describe()
# Out:
# count    3352.000000
# mean       10.955674
# std         5.945875
# min         0.000000
# 25%         7.500000
# 50%        10.000000
# 75%        12.400000
# max        67.100000
# Name: kitchen_meters, dtype: float64

# %%
sns.boxplot(x=df_c['kitchen_meters'], color = 'blue')
# Out:
# <Axes: xlabel='kitchen_meters'>

# %% [markdown]
# Удаляем строчки, где площадь кухни больше 45

# %%
df_c = df_c[df_c['kitchen_meters'] <= 45]

df_c['kitchen_meters'].describe()
# Out:
# count    3335.000000
# mean       10.744552
# std         5.149324
# min         0.000000
# 25%         7.500000
# 50%        10.000000
# 75%        12.200000
# max        45.000000
# Name: kitchen_meters, dtype: float64

# %%
# ещё раз выводим боксплот
sns.boxplot(x=df_c['kitchen_meters'], color = 'blue')
# Out:
# <Axes: xlabel='kitchen_meters'>

# %% [markdown]
# ---
#
# ### price

# %%
df_c['price'].describe()
# Out:
# count    3.335000e+03
# mean     1.127652e+07
# std      1.764544e+07
# min      1.500000e+06
# 25%      5.800000e+06
# 50%      8.100000e+06
# 75%      1.090000e+07
# max      3.093700e+08
# Name: price, dtype: float64

# %%
sns.boxplot(x=df_c['price'], color = 'pink')
# Out:
# <Axes: xlabel='price'>

# %%
# выводим 25 макс. значений
df_c.loc[df_c['price'].nlargest(25).index]
# Out:
#       location  floor  floors_count  rooms_count  total_meters      price  \
# 140         19      2            14            3        142.10  309370000
# 2973        19      3             6            4        166.00  278000000
# 193         19      6            10            2         96.00  260000000
# 1105        19     14            15            3        133.91  227647000
# 1845         1      4             6            2        137.00  214000000
# 1160        19     24            24            5        172.50  207000000
# 2968        19      3             9            4        130.00  205000000
# 151         19     14            17            3        169.50  200000000
# 1844         1      3             9            2        148.50  189000000
# 2982        19     13            16            4        158.00  180000000
# 741         19      2            14            2         85.60  175450000
# 138         19      5             5            3        183.10  174494300
# 770         19      2             5            2         64.00  172800000
# 1136        19     21            23            4        143.30  170000000
# 2975        19      6             7            4        167.50  157500000
# 3522        29      7             9            2        108.30  154000000
# 177         19      5             9            2        104.20  150958800
# 167         19     34            57            3        177.00  150000000
# 930         19      2            14            1         72.60  139410000
# 1166        19     17            17            5        148.00  120000000
# 593         11      9            21            3        117.00  115000000
# 188         19      9            68            2         92.00  110000000
# 3010        19      3             5            4        123.00  110000000
# 1139        19      3             9            4        143.00  108900000
# 928         19      4             6            1         59.35  101785250
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 140                 2024.0            0            5             4
# 2973                2023.0            0            1             3
# 193                 2014.0            1            0             4
# 1105                2022.0            1            2             4
# 1845                2018.0            1            0             0
# 1160                2024.0            0            0             0
# 2968                2021.0            1            0             0
# 151                 2003.0            1            0             4
# 1844                2023.0            1            0             4
# 2982                2017.0            1            0             4
# 741                 2024.0            0            1             4
# 138                 2017.0            0            0             4
# 770                 2021.0            1            0             0
# 1136                2014.0            1            0             4
# 2975                2019.0            1            0             4
# 3522                2023.0            1            0             4
# 177                 2023.0            0            0             4
# 167                 2006.0            1            0             4
# 930                 2024.0            0            0             4
# 1166                2022.0            1            0             0
# 593                 2023.0            1           11             4
# 188                 2020.0            1            0             4
# 3010                2017.0            1            0             0
# 1139                2021.0            1            0             4
# 928                 2024.0            0            2             1
#
#       living_meters  kitchen_meters  ceiling_height  street  underground
# 140            46.6           44.50            3.35    1418          216
# 2973           94.0           17.00            3.20    1076          111
# 193            80.0           16.00            3.40     388          192
# 1105           98.9           30.00            3.30     653          260
# 1845           58.0           15.70            2.81    1115          168
# 1160          104.6           10.50            3.20     794          294
# 2968          120.0           10.00            3.30    1111           90
# 151           149.5           20.00            3.00     761          142
# 1844           42.0           17.00            3.50     737          142
# 2982          109.0           15.00            3.20     845          214
# 741            34.6           15.50            3.35    1418           27
# 138            70.9           43.80            3.20    1074           14
# 770            57.0            7.00            3.40    1085          111
# 1136          124.2           14.10            2.90    1032          323
# 2975          147.5           20.00            3.50     990          145
# 3522           98.3           10.00            3.35     737          142
# 177            76.2           28.00            2.81     737          142
# 167           138.0           21.00            3.10    1213           15
# 930            14.2           31.00            3.35    1418          216
# 1166           70.0           27.00            3.00    1383          272
# 593           107.0           10.00            3.20     749          284
# 188            54.0           38.00            2.81     731          152
# 3010          108.0           15.00            3.50     410          106
# 1139           90.0           15.00            3.60    1130           92
# 928            48.9           10.45            2.81     346          115

# %% [markdown]
# Удаляем строки где цена больше 120000000

# %%
df_c = df_c[df_c['price'] < 120000000]

df_c['price'].describe()
# Out:
# count    3.315000e+03
# mean     1.018780e+07
# std      1.011766e+07
# min      1.500000e+06
# 25%      5.800000e+06
# 50%      8.027100e+06
# 75%      1.080000e+07
# max      1.150000e+08
# Name: price, dtype: float64

# %%
# снова график
sns.boxplot(x=df_c['price'], color = 'pink')
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# всё что за линией идёт +- сплошным рядом(?), оставим так

# %% [markdown]
# ---
#
# Выводим boxplot по всем колонкам

# %%
new_val_col = df_c[['floor', 'total_meters', 'price', 'living_meters', 'kitchen_meters']]

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 15))
# создаём боксплот для каждой колонки
for i, column in enumerate(new_val_col):
  row = i//3
  col = i % 3
  sns.boxplot(x=new_val_col[column], ax = axes[row, col], color = 'purple')
  axes[row, col].set_title(f'{column} boxplot')

plt.subplots_adjust(hspace = 0.9)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##Графики и анализ

# %%
df_c
# Out:
#       location  floor  floors_count  rooms_count  total_meters     price  \
# 1           27      1             9            1          33.0   4150000
# 4           27      4             7            1          25.9   3000000
# 9           27      6             9            2          42.7   3990000
# 10          27      1             5            2          42.8   2999000
# 13          27      1             3            1          25.3   2500000
# ...        ...    ...           ...          ...           ...       ...
# 8384        20      9            10            2          53.0   9500000
# 8385        20     17            17            2          52.2   9850000
# 8387        20      2             7            2          60.0  11950000
# 8388        20      8            14            2          69.7  11400000
# 8391        20      3             6            2          34.0   6400000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 1                   1975.0            1            0             0
# 4                   2009.0            1            0             2
# 9                   1980.0            1            2             2
# 10                  1990.0            1            1             2
# 13                  2015.0            1            2             0
# ...                    ...          ...          ...           ...
# 8384                2005.0            1            1             2
# 8385                2013.0            1            1             2
# 8387                2017.0            1            0             4
# 8388                2018.0            1            0             0
# 8391                2023.0            1            1             3
#
#       living_meters  kitchen_meters  ceiling_height  street  underground
# 1              18.0             6.0            2.70     160           12
# 4              20.0             5.0            3.50     671          325
# 9              29.7             5.6            2.70     831          325
# 10             24.9             6.0            2.50     711          325
# 13             14.1             6.2            2.80     599          325
# ...             ...             ...             ...     ...          ...
# 8384           28.0            11.0            2.60    1255          143
# 8385           27.0            10.9            2.80       8          143
# 8387           35.0            18.0            2.85    1057          143
# 8388           38.0            10.5            2.81    1238          143
# 8391           19.0             8.0            2.75    1289          143
#
# [3315 rows x 15 columns]

# %% [markdown]
# Смотрим количество квартир по комнатам

# %%
df_c.groupby('rooms_count').size().plot(kind='barh', color=sns.palettes.mpl_palette('Set2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Больше всего однокомнатных квартир, меньше всего 5-ти комнатных

# %%
df_c.groupby('object_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('ocean'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Вторичка = 1, Новостройка = 0
# --> Новостроек намного меньше (примерно в 9-10 раз)

# %%
 # выводим количество городов по колонке "location"
 len(df_c['location'].unique())
# Out:
# 37

# %%
plt.figure(figsize = (15,10))
df_c['location'].value_counts().sort_index().plot(kind='bar', title='location', color='pink')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %% [markdown]
# 'Балашиха': 0, 'Бекасово': 1, 'Видное': 2, 'Волоколамск': 3, 'Воскресенск': 4, 'Дзержинский': 5, 'Дмитров': 6, 'Долгопрудный': 7, 'Домодедово': 8, 'Дубна': 9, 'Звенигород': 10, 'Ивантеевка': 11, 'Клин': 12, 'Королёв': 13, 'Котельники': 14, 'Красногорск': 15, 'Краснозаводск': 16, 'Лобня': 17, 'Люберцы': 18, 'Москва': 19, 'Мытищи': 20, 'Ногинск': 21, 'Одинцово': 22, 'Пересвет': 23, 'Раменское': 24, 'Реутов': 25, 'Руза': 26, 'Серпухов': 27, 'Талдом': 28, 'Троицк': 29, 'Фрязино': 30, 'Химки': 31, 'Хотьково': 32, 'Черноголовка': 33, 'Шатура': 34, 'Щёлково': 35, 'Электросталь': 36, 'Яхрома': 37

# %% [markdown]
# * Больше всего среди данных квартир в Балашихе и в Химках

# %% [markdown]
# ---
#
#
# ## Добавляем столбик с ценой за квадратный метр

# %%
df_c = df_c.assign(price_per_square_meter = df_c['price'] // df_c['total_meters'])

# %%
df_c
# Out:
#       location  floor  floors_count  rooms_count  total_meters     price  \
# 1           27      1             9            1          33.0   4150000
# 4           27      4             7            1          25.9   3000000
# 9           27      6             9            2          42.7   3990000
# 10          27      1             5            2          42.8   2999000
# 13          27      1             3            1          25.3   2500000
# ...        ...    ...           ...          ...           ...       ...
# 8384        20      9            10            2          53.0   9500000
# 8385        20     17            17            2          52.2   9850000
# 8387        20      2             7            2          60.0  11950000
# 8388        20      8            14            2          69.7  11400000
# 8391        20      3             6            2          34.0   6400000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 1                   1975.0            1            0             0
# 4                   2009.0            1            0             2
# 9                   1980.0            1            2             2
# 10                  1990.0            1            1             2
# 13                  2015.0            1            2             0
# ...                    ...          ...          ...           ...
# 8384                2005.0            1            1             2
# 8385                2013.0            1            1             2
# 8387                2017.0            1            0             4
# 8388                2018.0            1            0             0
# 8391                2023.0            1            1             3
#
#       living_meters  kitchen_meters  ceiling_height  street  underground  \
# 1              18.0             6.0            2.70     160           12
# 4              20.0             5.0            3.50     671          325
# 9              29.7             5.6            2.70     831          325
# 10             24.9             6.0            2.50     711          325
# 13             14.1             6.2            2.80     599          325
# ...             ...             ...             ...     ...          ...
# 8384           28.0            11.0            2.60    1255          143
# 8385           27.0            10.9            2.80       8          143
# 8387           35.0            18.0            2.85    1057          143
# 8388           38.0            10.5            2.81    1238          143
# 8391           19.0             8.0            2.75    1289          143
#
#       price_per_square_meter
# 1                   125757.0
# 4                   115830.0
# 9                    93442.0
# 10                   70070.0
# 13                   98814.0
# ...                      ...
# 8384                179245.0
# 8385                188697.0
# 8387                199166.0
# 8388                163558.0
# 8391                188235.0
#
# [3315 rows x 16 columns]

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df_c.corr(), cmap = 'flare', annot = True)
plt.title('Матрица корреляции')
# Out:
# Text(0.5, 1.0, 'Матрица корреляции')

# %% [markdown]
# Вывод по матрице корреляции  ᯓ★
#
# * Стоимость квартиры зависит от этажа, этажности дома, года постройки, количества комнат, общей площади квартиры, площади кухни и жилой площади, высоты потолка и от стоимости за квадратный метр. + есть небольшая (0.21) корреляция с типом парковки
#
#
#  * Стоимость за квадратный метр зависит от этажа, этажности дома, цены, площади (общая площадь, площадь кухни и жилая), года постройки здания (больше чем общая стоимость квартиры), высоты потолка + от наличия парковки, но немного (0.19)
#
#  Стоимость квартиры и стоимость за квадратный метр зависят друг от друга

# %% [markdown]
# ---
#
# Сохраняем обработанный датасет на гугл диск

# %%
#df_c.to_csv('for_model.csv')

# %%
#from google.colab import drive
#drive.mount('drive')

# %%
#!cp for_model.csv "drive/My Drive/"
